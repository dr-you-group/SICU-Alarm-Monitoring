# %%
import os
import warnings
from datetime import timedelta
warnings.filterwarnings('ignore')
import pandas as pd
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

df_nurse_record = pd.read_csv("/Volumes/Seagate/new_nursing_0909.csv")
df_nurse_record = df_nurse_record[df_nurse_record['RecordUnit'] == 'ICUC']


unique_numbers_list = set(df_nurse_record['AlsUnitNo'].unique().tolist())
pkl_list = set([int(i.replace('.pkl', '')) for i in os.listdir('/Volumes/Seagate/pkl/') if i.endswith('.pkl')])

patient_id_list = list(pkl_list & unique_numbers_list)

# %%
# v1
# 
import pickle as pkl
import pandas as pd
from datetime import timedelta

def preprocess_data(patient_id):
    pickle = pkl.load(open(f'/Volumes/Seagate/pkl/{patient_id}.pkl', 'rb'))
    icuc = pickle[pickle['NURSING_RecordUnit']=='ICUC']

    # 필요한 컬럼 리스트
    required_columns = [
        'AlsUnitNo', 'TimeStamp', 'DatSeq',
        'Label', 'Severity',
        'ABP_WAVEFORM', 'ECG_WAVEFORM', 'PPG_WAVEFORM', 'RESP_WAVEFORM',
        'ABP_time_diff_sec', 'II_time_diff_sec', 'Pleth_time_diff_sec', 'Resp_time_diff_sec',
        'SpO2_numeric', 'Pulse_numeric', 'ST_numeric', 'Tskin_numeric', 
        'ABP_numeric', 'NBP_numeric', 'HR_numeric', 'RR_numeric',
        'SpO2_numeric_time_diff_sec', 'Pulse_numeric_time_diff_sec', 
        'ST_numeric_time_diff_sec', 'Tskin_numeric_time_diff_sec', 
        'ABP_numeric_time_diff_sec', 'NBP_numeric_time_diff_sec', 
        'HR_numeric_time_diff_sec', 'RR_numeric_time_diff_sec',
    ]
    
    # 모든 필요한 컬럼을 순서대로 생성
    filtered = pd.DataFrame()
    for col in required_columns:
        if col in icuc.columns:
            filtered[col] = icuc[col].copy()
        else:
            filtered[col] = pd.NA
            print(f"Warning: Missing column: {col}")
    
    # Severity 처리
    filtered['Severity'] = filtered['Severity'].apply(lambda x: x[0] if isinstance(x, list) and len(x) > 0 else None)
    filtered.insert(
        filtered.columns.get_loc('Severity')+1, 
        'SeverityColor', 
        filtered['Severity'].map({0: "Red", 1:"Yellow", 2:"ShortYellow", 3:"SevereCyan", 4:"Cyan", 5:"SilentCyan", 6:"White"})
    )

    filtered_nursing = df_nurse_record[df_nurse_record['AlsUnitNo'] == patient_id][
        ['TimeStamp', 'AssessmentNm', 'ImplementationNm', 'AttributeNm', 'AttributeDetail', 'AttributeDetailValue', 'AttributeDetailValue2', 'InDateTime', 'OutDateTime']
    ].sort_values('TimeStamp')

    # TimeStamp를 datetime으로 변환
    if filtered['TimeStamp'].dtype == 'object':
        filtered['TimeStamp'] = pd.to_datetime(filtered['TimeStamp'])
    if filtered_nursing['TimeStamp'].dtype == 'object':
        filtered_nursing['TimeStamp'] = pd.to_datetime(filtered_nursing['TimeStamp'])

    # 컬럼명 매핑
    column_mapping = {
        'TimeStamp': '시행일시',
        'AssessmentNm': '간호진단프로토콜(코드명)',
        'ImplementationNm': '간호활동(코드명)',
        'AttributeNm': '간호속성코드(코드명)',
        'AttributeDetail': '간호속성명칭',
        'AttributeDetailValue': '속성',
        'AttributeDetailValue2': '속성Text',
        'InDateTime': '입원시간',
        'OutDateTime': '퇴원기간'
    }

    # 앞 뒤로 둘 다 하나씩은 있어야함
    def get_nursing_records_optimized():
        result = []
        for idx, row in filtered.iterrows():
            timestamp = row['TimeStamp']
            start_time = timestamp - timedelta(minutes=30)
            end_time = timestamp + timedelta(minutes=30)
            
            # 이전 30분 레코드 확인
            before_mask = (filtered_nursing['TimeStamp'] >= start_time) & (filtered_nursing['TimeStamp'] < timestamp)
            before_records = filtered_nursing[before_mask]
            
            # 이후 30분 레코드 확인
            after_mask = (filtered_nursing['TimeStamp'] > timestamp) & (filtered_nursing['TimeStamp'] <= end_time)
            after_records = filtered_nursing[after_mask]
            
            # 한 쪽이라도 비어있으면 []
            if before_records.empty or after_records.empty:
                result.append([])
            else:
                # 전체 범위 레코드 가져오기
                mask = (filtered_nursing['TimeStamp'] >= start_time) & (filtered_nursing['TimeStamp'] <= end_time)
                records = filtered_nursing[mask]
                result.append(records.rename(columns=column_mapping).to_dict('records'))
        
        return result


    filtered['NursingRecords_ba30'] = get_nursing_records_optimized()

    # 필터링 조건 적용 - 존재하는 컬럼만 체크
    waveform_cols = ['ABP_time_diff_sec', 'II_time_diff_sec', 'Pleth_time_diff_sec', 'Resp_time_diff_sec']
    existing_waveform_cols = [col for col in waveform_cols if col in filtered.columns and filtered[col].notna().any()]
    
    # 조건 생성
    conditions = []
    
    # Waveform 컬럼 조건 (존재하는 컬럼만)
    if existing_waveform_cols:
        conditions.append((filtered[existing_waveform_cols] <= 60).all(axis=1))
    
    # NursingRecords 조건
    conditions.append(filtered['NursingRecords_ba30'].apply(lambda x: len(x) > 0))
    
    # 모든 조건 적용
    if conditions:
        final_mask = conditions[0]
        for condition in conditions[1:]:
            final_mask = final_mask & condition
        filtered = filtered[final_mask].copy()
    
    
    # 라벨 특수문자 제거
    filtered['Label'] = filtered['Label'].apply(lambda x: [item.replace('  ', ' ').replace('?', '').replace('!', '').strip() for item in x] if isinstance(x, list) else x)
    filtered['isView'] = True # 뷰어에선 안 보이고, False로 처리하고싶은 애들 (김정민 교수님 필터 참고해서 수정해야함.)
    
    # -------
    filtered['isSelected'] = False # 뷰어에서 T/F 가 선택되었나요? 의 여부
    filtered['isAlarm'] = False
    filtered['Comment'] = ''

    return filtered

# %%
# v2
import pickle as pkl
import pandas as pd
from datetime import timedelta

def preprocess_data(patient_id):
    pickle = pkl.load(open(f'/Volumes/Seagate/pkl/{patient_id}.pkl', 'rb'))
    icuc = pickle[pickle['NURSING_RecordUnit']=='ICUC']

    # 필요한 컬럼 리스트
    required_columns = [
        'AlsUnitNo', 'TimeStamp',
        'Label', 'Severity',
        'ABP_WAVEFORM', 'ECG_WAVEFORM', 'PPG_WAVEFORM', 'RESP_WAVEFORM',
        'ABP_time_diff_sec', 'II_time_diff_sec', 'Pleth_time_diff_sec', 'Resp_time_diff_sec',
        'SpO2_numeric', 'Pulse_numeric', 'ST_numeric', 'Tskin_numeric', 
        'ABP_numeric', 'NBP_numeric', 'HR_numeric', 'RR_numeric',
        'SpO2_numeric_time_diff_sec', 'Pulse_numeric_time_diff_sec', 
        'ST_numeric_time_diff_sec', 'Tskin_numeric_time_diff_sec', 
        'ABP_numeric_time_diff_sec', 'NBP_numeric_time_diff_sec', 
        'HR_numeric_time_diff_sec', 'RR_numeric_time_diff_sec',
    ]
    
    # 모든 필요한 컬럼을 순서대로 생성
    filtered = pd.DataFrame()
    for col in required_columns:
        if col in icuc.columns:
            filtered[col] = icuc[col].copy()
        else:
            filtered[col] = pd.NA
            print(f"Warning: Missing column: {col}")
    
    # Severity 처리
    filtered['Severity'] = filtered['Severity'].apply(lambda x: x[0] if isinstance(x, list) and len(x) > 0 else None)
    filtered.insert(
        filtered.columns.get_loc('Severity')+1, 
        'SeverityColor', 
        filtered['Severity'].map({0: "Red", 1:"Yellow", 2:"ShortYellow", 3:"SevereCyan", 4:"Cyan", 5:"SilentCyan", 6:"White"})
    )

    filtered_nursing = df_nurse_record[df_nurse_record['AlsUnitNo'] == patient_id][
        ['TimeStamp', 'AssessmentNm', 'ImplementationNm', 'AttributeNm', 'AttributeDetail', 'AttributeDetailValue', 'AttributeDetailValue2', 'InDateTime', 'OutDateTime']
    ].sort_values('TimeStamp')

    # TimeStamp를 datetime으로 변환
    if filtered['TimeStamp'].dtype == 'object':
        filtered['TimeStamp'] = pd.to_datetime(filtered['TimeStamp'])
    if filtered_nursing['TimeStamp'].dtype == 'object':
        filtered_nursing['TimeStamp'] = pd.to_datetime(filtered_nursing['TimeStamp'])

    # 컬럼명 매핑 (InDateTime, OutDateTime 제외)
    column_mapping = {
        'TimeStamp': '시행일시',
        'AssessmentNm': '간호진단프로토콜(코드명)',
        'ImplementationNm': '간호활동(코드명)',
        'AttributeNm': '간호속성코드(코드명)',
        'AttributeDetail': '간호속성명칭',
        'AttributeDetailValue': '속성',
        'AttributeDetailValue2': '속성Text'
    }

    # 앞 뒤로 둘 다 하나씩은 있어야함
    def get_nursing_records_optimized():
        result = []
        admission_in_list = []
        admission_out_list = []
        
        for idx, row in filtered.iterrows():
            timestamp = row['TimeStamp']
            start_time = timestamp - timedelta(minutes=30)
            end_time = timestamp + timedelta(minutes=30)
            
            # 이전 30분 레코드 확인
            before_mask = (filtered_nursing['TimeStamp'] >= start_time) & (filtered_nursing['TimeStamp'] < timestamp)
            before_records = filtered_nursing[before_mask]
            
            # 이후 30분 레코드 확인
            after_mask = (filtered_nursing['TimeStamp'] > timestamp) & (filtered_nursing['TimeStamp'] <= end_time)
            after_records = filtered_nursing[after_mask]
            
            # 한 쪽이라도 비어있으면 []
            if before_records.empty or after_records.empty:
                result.append([])
                admission_in_list.append('')
                admission_out_list.append('')
            else:
                # 전체 범위 레코드 가져오기
                mask = (filtered_nursing['TimeStamp'] >= start_time) & (filtered_nursing['TimeStamp'] <= end_time)
                records = filtered_nursing[mask]
                
                # 첫 번째 레코드의 InDateTime, OutDateTime 값 (단일 값)
                in_value = records['InDateTime'].iloc[0] if len(records) > 0 and pd.notna(records['InDateTime'].iloc[0]) else ''
                out_value = records['OutDateTime'].iloc[0] if len(records) > 0 and pd.notna(records['OutDateTime'].iloc[0]) else ''
                
                admission_in_list.append(in_value)
                admission_out_list.append(out_value)
                
                # NursingRecords에는 InDateTime, OutDateTime 제외하고 넣기
                records_without_admission = records.drop(columns=['InDateTime', 'OutDateTime'])
                result.append(records_without_admission.rename(columns=column_mapping).to_dict('records'))
        
        return result, admission_in_list, admission_out_list

    # 함수 호출 및 할당
    nursing_records, admission_ins, admission_outs = get_nursing_records_optimized()
    filtered['NursingRecords_ba30'] = nursing_records
    filtered['AdmissionIn'] = admission_ins
    filtered['AdmissionOut'] = admission_outs

    # 필터링 조건 적용 - 존재하는 컬럼만 체크
    waveform_cols = ['ABP_time_diff_sec', 'II_time_diff_sec', 'Pleth_time_diff_sec', 'Resp_time_diff_sec']
    existing_waveform_cols = [col for col in waveform_cols if col in filtered.columns and filtered[col].notna().any()]
    
    # 조건 생성
    conditions = []
    
    # Waveform 컬럼 조건 (존재하는 컬럼만)
    if existing_waveform_cols:
        conditions.append((filtered[existing_waveform_cols] <= 60).all(axis=1))
    
    # NursingRecords 조건
    conditions.append(filtered['NursingRecords_ba30'].apply(lambda x: len(x) > 0))
    
    # 모든 조건 적용
    if conditions:
        final_mask = conditions[0]
        for condition in conditions[1:]:
            final_mask = final_mask & condition
        filtered = filtered[final_mask].copy()
    
    # 라벨 특수문자 제거
    filtered['Label'] = filtered['Label'].apply(lambda x: [item.replace('  ', ' ').replace('?', '').replace('!', '').strip() for item in x] if isinstance(x, list) else x)
    
    # 나머지 컬럼들
    filtered['isView'] = True # 뷰어에선 안 보이고, False로 처리하고싶은 애들 (김정민 교수님 필터 참고해서 수정해야함.)
    filtered['isSelected'] = False # 뷰어에서 T/F 가 선택되었나요? 의 여부
    filtered['Classification'] = False
    filtered['Comment'] = ''

    return filtered

# %%
# v3
import pickle as pkl
import pandas as pd
from datetime import timedelta
from collections import Counter

# 기술적 알람 목록 로드
def load_technical_alarms(file_path="Filtered_AlarmLabelList.txt"):
    """기술적 알람 목록을 파일에서 로드하여 정규화"""
    technical_alarms = set()
    
    try:
        with open(file_path, 'r', encoding='utf-8') as f:
            lines = f.readlines()
        
        for line in lines:
            line = line.strip()
            if not line:  # 빈 줄 건너뛰기
                continue
            
            # 슬래시로 구분된 여러 라벨 처리
            if "/" in line:
                labels = [label.strip() for label in line.split("/")]
            else:
                labels = [line]
            
            # 각 라벨을 정규화하여 저장
            for label in labels:
                if label:  # 빈 문자열이 아닌 경우만
                    normalized_label = label.lower().strip().replace(" ", "")
                    if normalized_label:
                        technical_alarms.add(normalized_label)
        
        print(f"기술적 알람 목록 로드 완료: {len(technical_alarms)}개 라벨")
        
    except Exception as e:
        print(f"기술적 알람 목록 로드 오류: {e}")
    
    return technical_alarms

def normalize_alarm_label(label):
    """알람 라벨을 비교를 위해 정규화"""
    if not label:
        return ""
    return str(label).lower().replace(" ", "").strip()

def is_only_technical_alarms(label_list):
    """Label 리스트가 기술적 알람만 포함하는지 확인"""
    if not label_list or not isinstance(label_list, list):
        return False
    
    # 빈 리스트나 None만 있는 경우
    valid_labels = [label for label in label_list if label and str(label).strip() not in ["None", "[]", ""]]
    if not valid_labels:
        return False
    
    # 모든 라벨이 기술적 알람인지 확인
    for label in valid_labels:
        normalized_label = normalize_alarm_label(label)
        if normalized_label not in TECHNICAL_ALARMS:
            return False  # 하나라도 임상적 알람이 있으면 False
    
    return True  # 모두 기술적 알람인 경우만 True

# 전역 변수로 기술적 알람 목록 로드
TECHNICAL_ALARMS = load_technical_alarms()

def preprocess_data(patient_id):
    pickle = pkl.load(open(f'/Volumes/Seagate/pkl/{patient_id}.pkl', 'rb'))
    icuc = pickle[pickle['NURSING_RecordUnit']=='ICUC']

    # 필요한 컬럼 리스트
    required_columns = [
        'AlsUnitNo', 'TimeStamp',
        'Label', 'Severity',
        'ABP_WAVEFORM', 'ECG_WAVEFORM', 'PPG_WAVEFORM', 'RESP_WAVEFORM',
        'ABP_time_diff_sec', 'II_time_diff_sec', 'Pleth_time_diff_sec', 'Resp_time_diff_sec',
        'SpO2_numeric', 'Pulse_numeric', 'ST_numeric', 'Tskin_numeric', 
        'ABP_numeric', 'NBP_numeric', 'HR_numeric', 'RR_numeric',
        'SpO2_numeric_time_diff_sec', 'Pulse_numeric_time_diff_sec', 
        'ST_numeric_time_diff_sec', 'Tskin_numeric_time_diff_sec', 
        'ABP_numeric_time_diff_sec', 'NBP_numeric_time_diff_sec', 
        'HR_numeric_time_diff_sec', 'RR_numeric_time_diff_sec',
    ]
    
    # 모든 필요한 컬럼을 순서대로 생성
    filtered = pd.DataFrame()
    for col in required_columns:
        if col in icuc.columns:
            filtered[col] = icuc[col].copy()
        else:
            filtered[col] = pd.NA
            print(f"Warning: Missing column: {col}")
    
    # Severity 처리
    filtered['Severity'] = filtered['Severity'].apply(lambda x: x[0] if isinstance(x, list) and len(x) > 0 else None)
    filtered.insert(
        filtered.columns.get_loc('Severity')+1, 
        'SeverityColor', 
        filtered['Severity'].map({0: "Red", 1:"Yellow", 2:"ShortYellow", 3:"SevereCyan", 4:"Cyan", 5:"SilentCyan", 6:"White"})
    )

    filtered_nursing = df_nurse_record[df_nurse_record['AlsUnitNo'] == patient_id][
        ['TimeStamp', 'AssessmentNm', 'ImplementationNm', 'AttributeNm', 'AttributeDetail', 'AttributeDetailValue', 'AttributeDetailValue2', 'InDateTime', 'OutDateTime']
    ].sort_values('TimeStamp')

    # TimeStamp를 datetime으로 변환
    if filtered['TimeStamp'].dtype == 'object':
        filtered['TimeStamp'] = pd.to_datetime(filtered['TimeStamp'])
    if filtered_nursing['TimeStamp'].dtype == 'object':
        filtered_nursing['TimeStamp'] = pd.to_datetime(filtered_nursing['TimeStamp'])

    # 컬럼명 매핑 (InDateTime, OutDateTime 제외)
    column_mapping = {
        'TimeStamp': '시행일시',
        'AssessmentNm': '간호진단프로토콜(코드명)',
        'ImplementationNm': '간호활동(코드명)',
        'AttributeNm': '간호속성코드(코드명)',
        'AttributeDetail': '간호속성명칭',
        'AttributeDetailValue': '속성',
        'AttributeDetailValue2': '속성Text'
    }

    # 앞 뒤로 둘 다 하나씩은 있어야함
    def get_nursing_records_optimized():
        result = []
        admission_in_list = []
        admission_out_list = []
        
        for idx, row in filtered.iterrows():
            timestamp = row['TimeStamp']
            start_time = timestamp - timedelta(minutes=30)
            end_time = timestamp + timedelta(minutes=30)
            
            # 이전 30분 레코드 확인
            before_mask = (filtered_nursing['TimeStamp'] >= start_time) & (filtered_nursing['TimeStamp'] < timestamp)
            before_records = filtered_nursing[before_mask]
            
            # 이후 30분 레코드 확인
            after_mask = (filtered_nursing['TimeStamp'] > timestamp) & (filtered_nursing['TimeStamp'] <= end_time)
            after_records = filtered_nursing[after_mask]
            
            # 한 쪽이라도 비어있으면 []
            if before_records.empty or after_records.empty:
                result.append([])
                admission_in_list.append('')
                admission_out_list.append('')
            else:
                # 전체 범위 레코드 가져오기
                mask = (filtered_nursing['TimeStamp'] >= start_time) & (filtered_nursing['TimeStamp'] <= end_time)
                records = filtered_nursing[mask]
                
                # 첫 번째 레코드의 InDateTime, OutDateTime 값 (단일 값)
                in_value = records['InDateTime'].iloc[0] if len(records) > 0 and pd.notna(records['InDateTime'].iloc[0]) else ''
                out_value = records['OutDateTime'].iloc[0] if len(records) > 0 and pd.notna(records['OutDateTime'].iloc[0]) else ''
                
                admission_in_list.append(in_value)
                admission_out_list.append(out_value)
                
                # NursingRecords에는 InDateTime, OutDateTime 제외하고 넣기
                records_without_admission = records.drop(columns=['InDateTime', 'OutDateTime'])
                result.append(records_without_admission.rename(columns=column_mapping).to_dict('records'))
        
        return result, admission_in_list, admission_out_list

    # 함수 호출 및 할당
    nursing_records, admission_ins, admission_outs = get_nursing_records_optimized()
    filtered['NursingRecords_ba30'] = nursing_records
    filtered['AdmissionIn'] = admission_ins
    filtered['AdmissionOut'] = admission_outs

    # 필터링 조건 적용 - 존재하는 컬럼만 체크
    waveform_cols = ['ABP_time_diff_sec', 'II_time_diff_sec', 'Pleth_time_diff_sec', 'Resp_time_diff_sec']
    waveform_cols += ['SpO2_numeric_time_diff_sec', 'Pulse_numeric_time_diff_sec', 
        'ST_numeric_time_diff_sec', 'Tskin_numeric_time_diff_sec', 
        'ABP_numeric_time_diff_sec', 'NBP_numeric_time_diff_sec', 
        'HR_numeric_time_diff_sec', 'RR_numeric_time_diff_sec',]
    existing_waveform_cols = [col for col in waveform_cols if col in filtered.columns and filtered[col].notna().any()]
    
    # 조건 생성
    conditions = []
    
    # Waveform 컬럼 조건 (존재하는 컬럼만)
    if existing_waveform_cols:
        conditions.append((filtered[existing_waveform_cols] <= 60).all(axis=1))
    
    # NursingRecords 조건
    conditions.append(filtered['NursingRecords_ba30'].apply(lambda x: len(x) > 0))
    
    # 모든 조건 적용
    if conditions:
        final_mask = conditions[0]
        for condition in conditions[1:]:
            final_mask = final_mask & condition
        filtered = filtered[final_mask].copy()
    
    # 라벨 특수문자 제거
    filtered['Label'] = filtered['Label'].apply(lambda x: [item.replace('  ', ' ').replace('?', '').replace('!', '').strip() for item in x] if isinstance(x, list) else x)
    
    # 기술적 알람 필터링 전 통계 수집
    before_count = len(filtered)
    technical_alarm_counter = Counter()
    
    # 제거될 기술적 알람들 카운팅
    for idx, row in filtered.iterrows():
        if is_only_technical_alarms(row['Label']):
            if isinstance(row['Label'], list):
                for label in row['Label']:
                    if label and str(label).strip() not in ["None", "[]", ""]:
                        technical_alarm_counter[label] += 1
    
    # 기술적 알람만 있는 행 필터링
    filtered = filtered[~filtered['Label'].apply(is_only_technical_alarms)].copy()
    
    # 필터링 후 통계 출력
    after_count = len(filtered)
    removed_count = before_count - after_count
    
    print(f"\n=== 기술적 알람 필터링 결과 ===")
    print(f"필터링 전 데이터: {before_count}개")
    print(f"필터링 후 데이터: {after_count}개")
    print(f"제거된 데이터: {removed_count}개")
    
    if technical_alarm_counter:
        print(f"\n제거된 기술적 알람 종류별 개수:")
        for alarm, count in technical_alarm_counter.most_common():
            print(f"  - {alarm}: {count}개")
    
    # 나머지 컬럼들
    filtered['isView'] = True # 뷰어에선 안 보이고, False로 처리하고싶은 애들 (김정민 교수님 필터 참고해서 수정해야함.)
    filtered['isSelected'] = False # 뷰어에서 T/F 가 선택되었나요? 의 여부
    filtered['Classification'] = False
    filtered['Comment'] = ''

    return filtered
# Out:
# 기술적 알람 목록 로드 완료: 55개 라벨

# %%
# v4
import pickle as pkl
import pandas as pd
from datetime import timedelta
from collections import Counter

# 기술적 알람 목록 로드
def load_technical_alarms(file_path="Filtered_AlarmLabelList.txt"):
    """기술적 알람 목록을 파일에서 로드하여 정규화"""
    technical_alarms = set()
    
    try:
        with open(file_path, 'r', encoding='utf-8') as f:
            lines = f.readlines()
        
        for line in lines:
            line = line.strip()
            if not line:  # 빈 줄 건너뛰기
                continue
            
            # 슬래시로 구분된 여러 라벨 처리
            if "/" in line:
                labels = [label.strip() for label in line.split("/")]
            else:
                labels = [line]
            
            # 각 라벨을 정규화하여 저장
            for label in labels:
                if label:  # 빈 문자열이 아닌 경우만
                    normalized_label = label.lower().strip().replace(" ", "")
                    if normalized_label:
                        technical_alarms.add(normalized_label)
        
        print(f"기술적 알람 목록 로드 완료: {len(technical_alarms)}개 라벨")
        
    except Exception as e:
        print(f"기술적 알람 목록 로드 오류: {e}")
    
    return technical_alarms

def normalize_alarm_label(label):
    """알람 라벨을 비교를 위해 정규화"""
    if not label:
        return ""
    return str(label).lower().replace(" ", "").strip()

def is_only_technical_alarms(label_list):
    """Label 리스트가 기술적 알람만 포함하는지 확인"""
    if not label_list or not isinstance(label_list, list):
        return False
    
    # 빈 리스트나 None만 있는 경우
    valid_labels = [label for label in label_list if label and str(label).strip() not in ["None", "[]", ""]]
    if not valid_labels:
        return False
    
    # 모든 라벨이 기술적 알람인지 확인
    for label in valid_labels:
        normalized_label = normalize_alarm_label(label)
        if normalized_label not in TECHNICAL_ALARMS:
            return False  # 하나라도 임상적 알람이 있으면 False
    
    return True  # 모두 기술적 알람인 경우만 True

# 전역 변수로 기술적 알람 목록 로드
TECHNICAL_ALARMS = load_technical_alarms()

def preprocess_data(patient_id):
    pickle = pkl.load(open(f'/Volumes/Seagate/pkl/{patient_id}.pkl', 'rb'))
    icuc = pickle[pickle['NURSING_RecordUnit']=='ICUC']

    # 필요한 컬럼 리스트
    required_columns = [
        'AlsUnitNo', 'TimeStamp',
        'Label', 'Severity',
        'ABP_WAVEFORM', 'ECG_WAVEFORM', 'PPG_WAVEFORM', 'RESP_WAVEFORM',
        'ABP_time_diff_sec', 'II_time_diff_sec', 'Pleth_time_diff_sec', 'Resp_time_diff_sec',
        'SpO2_numeric', 'Pulse_numeric', 'ST_numeric', 'Tskin_numeric', 
        'ABP_numeric', 'NBP_numeric', 'HR_numeric', 'RR_numeric',
        'SpO2_numeric_time_diff_sec', 'Pulse_numeric_time_diff_sec', 
        'ST_numeric_time_diff_sec', 'Tskin_numeric_time_diff_sec', 
        'ABP_numeric_time_diff_sec', 'NBP_numeric_time_diff_sec', 
        'HR_numeric_time_diff_sec', 'RR_numeric_time_diff_sec',
    ]
    
    # 모든 필요한 컬럼을 순서대로 생성
    filtered = pd.DataFrame()
    for col in required_columns:
        if col in icuc.columns:
            filtered[col] = icuc[col].copy()
        else:
            filtered[col] = pd.NA
            print(f"Warning: Missing column: {col}")
    
    # Severity 처리
    filtered['Severity'] = filtered['Severity'].apply(lambda x: x[0] if isinstance(x, list) and len(x) > 0 else None)
    filtered.insert(
        filtered.columns.get_loc('Severity')+1, 
        'SeverityColor', 
        filtered['Severity'].map({0: "Red", 1:"Yellow", 2:"ShortYellow", 3:"SevereCyan", 4:"Cyan", 5:"SilentCyan", 6:"White"})
    )

    filtered_nursing = df_nurse_record[df_nurse_record['AlsUnitNo'] == patient_id][
        ['TimeStamp', 'AssessmentNm', 'ImplementationNm', 'AttributeNm', 'AttributeDetail', 'AttributeDetailValue', 'AttributeDetailValue2', 'InDateTime', 'OutDateTime']
    ].sort_values('TimeStamp')

    # TimeStamp를 datetime으로 변환
    if filtered['TimeStamp'].dtype == 'object':
        filtered['TimeStamp'] = pd.to_datetime(filtered['TimeStamp'])
    if filtered_nursing['TimeStamp'].dtype == 'object':
        filtered_nursing['TimeStamp'] = pd.to_datetime(filtered_nursing['TimeStamp'])

    # 컬럼명 매핑 (InDateTime, OutDateTime 제외)
    column_mapping = {
        'TimeStamp': '시행일시',
        'AssessmentNm': '간호진단프로토콜(코드명)',
        'ImplementationNm': '간호활동(코드명)',
        'AttributeNm': '간호속성코드(코드명)',
        'AttributeDetail': '간호속성명칭',
        'AttributeDetailValue': '속성',
        'AttributeDetailValue2': '속성Text'
    }

    # 앞 뒤로 둘 다 하나씩은 있어야함
    def get_nursing_records_optimized():
        result = []
        admission_in_list = []
        admission_out_list = []
        in_out_consistency_list = []  # In/Out 시간 일관성 체크 리스트 추가
        
        for idx, row in filtered.iterrows():
            timestamp = row['TimeStamp']
            start_time = timestamp - timedelta(minutes=30)
            end_time = timestamp + timedelta(minutes=30)
            
            # 이전 30분 레코드 확인
            before_mask = (filtered_nursing['TimeStamp'] >= start_time) & (filtered_nursing['TimeStamp'] < timestamp)
            before_records = filtered_nursing[before_mask]
            
            # 이후 30분 레코드 확인
            after_mask = (filtered_nursing['TimeStamp'] > timestamp) & (filtered_nursing['TimeStamp'] <= end_time)
            after_records = filtered_nursing[after_mask]
            
            # 한 쪽이라도 비어있으면 []
            if before_records.empty or after_records.empty:
                result.append([])
                admission_in_list.append('')
                admission_out_list.append('')
                in_out_consistency_list.append(False)  # 데이터가 없으므로 일관성도 False
            else:
                # 전체 범위 레코드 가져오기
                mask = (filtered_nursing['TimeStamp'] >= start_time) & (filtered_nursing['TimeStamp'] <= end_time)
                records = filtered_nursing[mask]
                
                # In/Out 시간 일관성 체크
                unique_in_times = records['InDateTime'].dropna().unique()
                unique_out_times = records['OutDateTime'].dropna().unique()
                
                # 모든 간호기록의 InDateTime과 OutDateTime이 각각 동일한지 확인
                # NaN이 아닌 값들 중에서 unique 값이 1개만 있어야 일관성 있음
                is_consistent = (len(unique_in_times) <= 1) and (len(unique_out_times) <= 1)
                in_out_consistency_list.append(is_consistent)
                
                # 첫 번째 레코드의 InDateTime, OutDateTime 값 (단일 값)
                in_value = records['InDateTime'].iloc[0] if len(records) > 0 and pd.notna(records['InDateTime'].iloc[0]) else ''
                out_value = records['OutDateTime'].iloc[0] if len(records) > 0 and pd.notna(records['OutDateTime'].iloc[0]) else ''
                
                admission_in_list.append(in_value)
                admission_out_list.append(out_value)
                
                # NursingRecords에는 InDateTime, OutDateTime 제외하고 넣기
                records_without_admission = records.drop(columns=['InDateTime', 'OutDateTime'])
                result.append(records_without_admission.rename(columns=column_mapping).to_dict('records'))
        
        return result, admission_in_list, admission_out_list, in_out_consistency_list

    # 함수 호출 및 할당
    nursing_records, admission_ins, admission_outs, in_out_consistency = get_nursing_records_optimized()
    filtered['NursingRecords_ba30'] = nursing_records
    filtered['AdmissionIn'] = admission_ins
    filtered['AdmissionOut'] = admission_outs
    filtered['InOutConsistent'] = in_out_consistency  # 일관성 플래그 추가

    # In/Out 시간 일관성 필터링 전 통계
    inconsistent_count = (~filtered['InOutConsistent']).sum()
    print(f"\n=== In/Out 시간 일관성 체크 ===")
    print(f"In/Out 시간이 일관되지 않은 알람 개수: {inconsistent_count}개")

    # 필터링 조건 적용 - 존재하는 컬럼만 체크
    waveform_cols = ['ABP_time_diff_sec', 'II_time_diff_sec', 'Pleth_time_diff_sec', 'Resp_time_diff_sec']
    waveform_cols += ['SpO2_numeric_time_diff_sec', 'Pulse_numeric_time_diff_sec', 
        'ST_numeric_time_diff_sec', 'Tskin_numeric_time_diff_sec', 
        'ABP_numeric_time_diff_sec', 'NBP_numeric_time_diff_sec', 
        'HR_numeric_time_diff_sec', 'RR_numeric_time_diff_sec',]
    existing_waveform_cols = [col for col in waveform_cols if col in filtered.columns and filtered[col].notna().any()]
    
    # 조건 생성
    conditions = []
    
    # Waveform 컬럼 조건 (존재하는 컬럼만)
    if existing_waveform_cols:
        conditions.append((filtered[existing_waveform_cols] <= 60).all(axis=1))
    
    # NursingRecords 조건
    conditions.append(filtered['NursingRecords_ba30'].apply(lambda x: len(x) > 0))
    
    # In/Out 시간 일관성 조건 추가
    conditions.append(filtered['InOutConsistent'])
    
    # 모든 조건 적용
    if conditions:
        final_mask = conditions[0]
        for condition in conditions[1:]:
            final_mask = final_mask & condition
        filtered = filtered[final_mask].copy()
    
    # InOutConsistent 컬럼 제거 (최종 데이터에는 필요 없음)
    filtered = filtered.drop(columns=['InOutConsistent'])
    
    # 라벨 특수문자 제거
    filtered['Label'] = filtered['Label'].apply(lambda x: [item.replace('  ', ' ').replace('?', '').replace('!', '').strip() for item in x] if isinstance(x, list) else x)
    
    # # 기술적 알람 필터링 전 통계 수집
    # before_count = len(filtered)
    # technical_alarm_counter = Counter()
    
    # # 제거될 기술적 알람들 카운팅
    # for idx, row in filtered.iterrows():
    #     if is_only_technical_alarms(row['Label']):
    #         if isinstance(row['Label'], list):
    #             for label in row['Label']:
    #                 if label and str(label).strip() not in ["None", "[]", ""]:
    #                     technical_alarm_counter[label] += 1
    
    # # 기술적 알람만 있는 행 필터링
    # filtered = filtered[~filtered['Label'].apply(is_only_technical_alarms)].copy()
    
    # # 필터링 후 통계 출력
    # after_count = len(filtered)
    # removed_count = before_count - after_count
    
    # print(f"\n=== 기술적 알람 필터링 결과 ===")
    # print(f"필터링 전 데이터: {before_count}개")
    # print(f"필터링 후 데이터: {after_count}개")
    # print(f"제거된 데이터: {removed_count}개")
    
    # if technical_alarm_counter:
    #     print(f"\n제거된 기술적 알람 종류별 개수:")
    #     for alarm, count in technical_alarm_counter.most_common():
    #         print(f"  - {alarm}: {count}개")
    
    # 나머지 컬럼들
    filtered['isView'] = True # 뷰어에선 안 보이고, False로 처리하고싶은 애들 (김정민 교수님 필터 참고해서 수정해야함.)
    filtered['isSelected'] = False # 뷰어에서 T/F 가 선택되었나요? 의 여부
    filtered['Classification'] = False
    filtered['Comment'] = ''

    return filtered
# Out:
# 기술적 알람 목록 로드 완료: 55개 라벨

# %%
import pickle as pkl
import os

def save_processed_data(patient_id, output_dir='/Volumes/Seagate/pre_processed1/'):
    filtered = preprocess_data(patient_id)
    
    if len(filtered) > 0:
        if not os.path.exists(output_dir):
            os.makedirs(output_dir)
        
        output_path = os.path.join(output_dir, f'{patient_id}_processed.pkl')
        with open(output_path, 'wb') as f:
            pkl.dump(filtered, f)
        print(f"{patient_id}: {len(filtered)} rows saved")
    else:
        print(f"{patient_id}: No rows, skipped")

def batch_process(patient_ids):
    for patient_id in patient_ids:
        try:
            save_processed_data(patient_id)
        except Exception as e:
            print(f"{patient_id}: Error - {e}")


for i in patient_id_list:
    try:
        filtered = preprocess_data(i)
        if len(filtered) > 0:
            with open(f'/Volumes/Seagate/pre_processed1/{i}.pkl', 'wb') as f:
                pkl.dump(filtered, f)
            print(f"{i}: {len(filtered)} rows saved")
        else:
            print(f"{i}: No rows, skipped")
    except Exception as e:
        print(f"{i}: Error - {e}")
# Out:
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 0.0개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 8660993: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 44개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 8개
# 필터링 후 데이터: 6개
# 제거된 데이터: 2개
#
# 제거된 기술적 알람 종류별 개수:
#   - PPV bad ABP Signal: 2개
# 11526147: 6 rows saved
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 0.0개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 11466763: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 0.0개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 1949715: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 66개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 11319320: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 0.0개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 11448345: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 2168개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 16개
# 필터링 후 데이터: 12개
# 제거된 데이터: 4개
#
# 제거된 기술적 알람 종류별 개수:
#   - Alarms Paused: 4개
# 10532891: 12 rows saved
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 724개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 11059230: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 131개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 9개
# 필터링 후 데이터: 2개
# 제거된 데이터: 7개
#
# 제거된 기술적 알람 종류별 개수:
#   - PPV bad ABP Signal: 7개
# 11618341: 2 rows saved
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 361개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 25개
# 필터링 후 데이터: 5개
# 제거된 데이터: 20개
#
# 제거된 기술적 알람 종류별 개수:
#   - ABP  Change Scale: 19개
#   - Alarms Paused: 3개
# 10811448: 5 rows saved
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 0.0개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 2586684: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 0.0개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 11456575: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 0.0개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 11452483: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 0.0개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 11460687: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 0.0개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 11417682: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 3325개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 9648217: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 481개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 10개
# 필터링 후 데이터: 6개
# 제거된 데이터: 4개
#
# 제거된 기술적 알람 종류별 개수:
#   - Alarms Paused: 1개
#   - ECG  Leads Off: 1개
#   - Resp  Leads Off: 1개
#   - SpO2  No Sensor: 1개
#   - SpO2  Low Perf: 1개
# 10264681: 6 rows saved
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 0.0개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 4526187: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 0.0개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 11405419: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 0.0개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 4776045: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 6226개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 9879666: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 9495개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 116개
# 필터링 후 데이터: 82개
# 제거된 데이터: 34개
#
# 제거된 기술적 알람 종류별 개수:
#   - PPV bad ABP Signal: 8개
#   - ABP No Pulse: 7개
#   - ECG  Leads Off: 6개
#   - Resp  Leads Off: 6개
#   - Alarms Paused: 5개
#   - SpO2  Low Perf: 3개
#   - ABP Noisy Signal: 2개
#   - ABP  Change Scale: 2개
#   - ABP Artifact: 1개
#   - Tskin NoTransducer: 1개
#   - SpO2  No Sensor: 1개
#   - NBP Interrupted: 1개
#   - SpO2  NoisySignal: 1개
#   - ABP Overrange: 1개
# 11688056: 82 rows saved
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 175개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 10645625: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 0.0개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 11417722: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 14118개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 11350145: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 10700개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 11079810: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 0.0개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 11393161: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 0.0개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 4685968: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 0.0개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 3723418: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 0.0개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 9971876: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 378개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 11559076: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 0.0개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 11421863: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 0.0개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 2937002: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 43개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 10842283: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 0.0개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 11542704: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 0.0개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 11520179: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 0.0개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 11407540: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 80개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 11505853: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 1096개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 37개
# 필터링 후 데이터: 21개
# 제거된 데이터: 16개
#
# 제거된 기술적 알람 종류별 개수:
#   - PPV bad ABP Signal: 11개
#   - ABP No Pulse: 5개
#   - ABP Artifact: 3개
#   - ECG  Leads Off: 2개
#   - Resp  Leads Off: 2개
# 10240203: 21 rows saved
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 389개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 8개
# 필터링 후 데이터: 3개
# 제거된 데이터: 5개
#
# 제거된 기술적 알람 종류별 개수:
#   - PPV bad ABP Signal: 2개
#   - SpO2  Low Perf: 2개
#   - Tskin NoTransducer: 2개
#   - ABP No Pulse: 1개
#   - ABP Artifact: 1개
# 11591884: 3 rows saved
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 0.0개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 11563213: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 1272개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 29개
# 필터링 후 데이터: 24개
# 제거된 데이터: 5개
#
# 제거된 기술적 알람 종류별 개수:
#   - Tskin NoTransducer: 3개
#   - ECG  Leads Off: 1개
#   - Resp  Leads Off: 1개
#   - Alarms Paused: 1개
# 10391780: 24 rows saved
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 0.0개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 2285799: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 0.0개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 11419879: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 62개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 10개
# 필터링 후 데이터: 7개
# 제거된 데이터: 3개
#
# 제거된 기술적 알람 종류별 개수:
#   - ABP  Change Scale: 2개
#   - Alarms Paused: 1개
# 10162411: 7 rows saved
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 0.0개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 11411692: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 115개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 10918137: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 132개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 5개
# 필터링 후 데이터: 1개
# 제거된 데이터: 4개
#
# 제거된 기술적 알람 종류별 개수:
#   - ABP No Pulse: 3개
#   - Resp  Leads Off: 1개
#   - ECG  Leads Off: 1개
# 11522301: 1 rows saved
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 0.0개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 11438336: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 0.0개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 4557066: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 83개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 9개
# 필터링 후 데이터: 4개
# 제거된 데이터: 5개
#
# 제거된 기술적 알람 종류별 개수:
#   - Alarms Paused: 2개
#   - SpO2  No Sensor: 1개
#   - PPV bad ABP Signal: 1개
#   - PPV  Chk Sources: 1개
# 11510026: 4 rows saved
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 0.0개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 11411731: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 33개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 30개
# 필터링 후 데이터: 25개
# 제거된 데이터: 5개
#
# 제거된 기술적 알람 종류별 개수:
#   - PPV bad ABP Signal: 3개
#   - ABP No Pulse: 2개
#   - Alarms Paused: 1개
# 11604245: 25 rows saved
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 0.0개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 11442457: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 0.0개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 4835610: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 31개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 11323679: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 0.0개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 11495713: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 0.0개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 11456806: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 20240개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 11개
# 필터링 후 데이터: 10개
# 제거된 데이터: 1개
#
# 제거된 기술적 알람 종류별 개수:
#   - SpO2  Low Perf: 1개
# 11594026: 10 rows saved
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 3127개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 131개
# 필터링 후 데이터: 85개
# 제거된 데이터: 46개
#
# 제거된 기술적 알람 종류별 개수:
#   - SpO2  Low Perf: 8개
#   - Tskin NoTransducer: 8개
#   - SpO2 Interference: 8개
#   - PPV bad ABP Signal: 8개
#   - Alarms Paused: 7개
#   - SpO2  NoisySignal: 5개
#   - LL Lead Off: 3개
#   - Resp  Leads Off: 3개
#   - ABP Artifact: 3개
#   - ABP  Change Scale: 1개
# 10352939: 85 rows saved
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 287개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 11542837: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 0.0개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 11538752: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 0.0개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 11426113: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 1925개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 21개
# 필터링 후 데이터: 17개
# 제거된 데이터: 4개
#
# 제거된 기술적 알람 종류별 개수:
#   - ABP  Change Scale: 4개
# 10848582: 17 rows saved
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 0.0개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 2625866: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 0.0개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 11268426: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 0.0개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 1325389: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 0.0개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 4010318: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 1976개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 228개
# 필터링 후 데이터: 112개
# 제거된 데이터: 116개
#
# 제거된 기술적 알람 종류별 개수:
#   - PPV bad ABP Signal: 69개
#   - ABP No Pulse: 47개
#   - Alarms Paused: 29개
#   - ABP Artifact: 4개
#   - ABP  Change Scale: 4개
#   - Resp  Leads Off: 4개
#   - ABP Noisy Signal: 2개
#   - ECG  Leads Off: 2개
#   - NBP Check Cuff: 1개
# 9910609: 112 rows saved
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 212개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 12개
# 필터링 후 데이터: 2개
# 제거된 데이터: 10개
#
# 제거된 기술적 알람 종류별 개수:
#   - Resp  Leads Off: 4개
#   - ECG  Leads Off: 4개
#   - Tskin NoTransducer: 3개
#   - PPV bad ABP Signal: 3개
#   - SpO2  Low Perf: 1개
#   - Alarms Paused: 1개
#   - ABP No Transducer: 1개
#   - PPV  Chk Sources: 1개
# 10670417: 2 rows saved
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 0.0개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 11483475: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 0.0개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 3756372: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 14개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 11520345: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 627개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 74개
# 필터링 후 데이터: 50개
# 제거된 데이터: 24개
#
# 제거된 기술적 알람 종류별 개수:
#   - SpO2  Low Perf: 19개
#   - ECG  Leads Off: 3개
#   - Resp  Leads Off: 3개
#   - ABP Artifact: 2개
#   - LL Lead Off: 1개
#   - PPV bad ABP Signal: 1개
# 11508059: 50 rows saved
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 126개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 11657563: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 0.0개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 1708385: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 105개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 10938731: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 0개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 10940785: No rows, skipped
# Warning: Missing column: ST_numeric_time_diff_sec
# Warning: Missing column: Tskin_numeric_time_diff_sec
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 0개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 10031477: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 0.0개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 2535799: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 18799개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 481개
# 필터링 후 데이터: 279개
# 제거된 데이터: 202개
#
# 제거된 기술적 알람 종류별 개수:
#   - SpO2  Low Perf: 119개
#   - Alarms Paused: 38개
#   - PPV bad ABP Signal: 19개
#   - SpO2 Interference: 16개
#   - ABP Artifact: 9개
#   - ABP Noisy Signal: 8개
#   - ABP No Pulse: 6개
#   - SpO2  NoisySignal: 5개
#   - SpO2  No Sensor: 2개
#   - ABP  Change Scale: 2개
#   - ECG  Leads Off: 2개
#   - Resp  Leads Off: 2개
#   - ABP Overrange: 2개
#   - SpO2  Sensor Off: 1개
#   - SpO2  Sensor Malf: 1개
#   - ABP No Transducer: 1개
#   - NBP  Equip Malf: 1개
# 11518327: 279 rows saved
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 0.0개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 4405638: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 0.0개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 11489671: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 469개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 11655558: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 126개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 12개
# 필터링 후 데이터: 9개
# 제거된 데이터: 3개
#
# 제거된 기술적 알람 종류별 개수:
#   - SpO2  Low Perf: 3개
# 11352461: 9 rows saved
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 0.0개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 4858257: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 0.0개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 11393431: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 82개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 11571617: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 9147개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 9773481: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 0.0개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 11590072: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 102개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 2개
# 필터링 후 데이터: 0개
# 제거된 데이터: 2개
#
# 제거된 기술적 알람 종류별 개수:
#   - PPV bad ABP Signal: 2개
#   - ABP No Pulse: 1개
# 11608510: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 0.0개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 11565513: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 0.0개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 4688333: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 106개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 11540956: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 0.0개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 2904558: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 0.0개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 11581935: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 0.0개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 11434481: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 0.0개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 11356658: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 137개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 11543033: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 77개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 9961978: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 0.0개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 4567551: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 0.0개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 11479558: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 251개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 11426311: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 354개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 14개
# 필터링 후 데이터: 3개
# 제거된 데이터: 11개
#
# 제거된 기술적 알람 종류별 개수:
#   - Tskin NoTransducer: 4개
#   - PPV bad ABP Signal: 3개
#   - ABP Artifact: 3개
#   - Alarms Paused: 1개
#   - ABP No Pulse: 1개
# 11573770: 3 rows saved
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 0.0개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 11452942: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 0.0개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 11491856: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 51개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 11651611: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 0.0개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 4084252: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 0.0개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 2261538: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 367개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 11684395: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 0.0개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 2452019: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 77개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 11678265: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 0.0개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 2886204: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 913개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 32개
# 필터링 후 데이터: 10개
# 제거된 데이터: 22개
#
# 제거된 기술적 알람 종류별 개수:
#   - Alarms Paused: 15개
#   - ABP No Pulse: 10개
#   - ABP Noisy Signal: 6개
#   - PPV bad ABP Signal: 3개
#   - Tskin NoTransducer: 1개
#   - ABP Disconnect: 1개
#   - ABP Artifact: 1개
#   - ABP  Change Scale: 1개
# 11606591: 10 rows saved
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 0.0개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 2968129: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 0.0개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 11414084: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 0.0개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 11575878: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 0.0개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 11543117: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 488개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 7개
# 필터링 후 데이터: 2개
# 제거된 데이터: 5개
#
# 제거된 기술적 알람 종류별 개수:
#   - ABP No Pulse: 2개
#   - PPV bad ABP Signal: 2개
#   - Alarms Paused: 1개
#   - ECG  Leads Off: 1개
#   - Resp  Leads Off: 1개
#   - ABP Artifact: 1개
# 10816078: 2 rows saved
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 0.0개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 11588174: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 366개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 13개
# 필터링 후 데이터: 8개
# 제거된 데이터: 5개
#
# 제거된 기술적 알람 종류별 개수:
#   - Alarms Paused: 3개
#   - PPV bad ABP Signal: 1개
#   - ABP No Pulse: 1개
# 11559506: 8 rows saved
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 0.0개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 2384467: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 198개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 8개
# 필터링 후 데이터: 5개
# 제거된 데이터: 3개
#
# 제거된 기술적 알람 종류별 개수:
#   - Alarms Paused: 2개
#   - ABP Artifact: 1개
# 11207254: 5 rows saved
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 441개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 33개
# 필터링 후 데이터: 22개
# 제거된 데이터: 11개
#
# 제거된 기술적 알람 종류별 개수:
#   - Alarms Paused: 4개
#   - Tskin NoTransducer: 4개
#   - ECG  Leads Off: 2개
#   - Resp  Leads Off: 2개
#   - SpO2 Interference: 1개
#   - SpO2  NoisySignal: 1개
#   - SpO2  Low Perf: 1개
#   - NBP Interrupted: 1개
# 11563609: 22 rows saved
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 0.0개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 9445980: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 0.0개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 1858145: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 0.0개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 11428456: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 4215개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 24개
# 필터링 후 데이터: 16개
# 제거된 데이터: 8개
#
# 제거된 기술적 알람 종류별 개수:
#   - SpO2  Low Perf: 4개
#   - Alarms Paused: 3개
#   - SpO2 Interference: 1개
#   - SpO2  NoisySignal: 1개
# 10697326: 16 rows saved
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 0.0개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 11532910: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 0.0개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 11491954: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 0.0개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 6417027: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 84개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 11602568: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 522개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 11354763: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 0.0개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 11395724: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 0.0개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 4565646: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 0.0개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 2689681: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 0.0개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 11549329: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 0.0개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 1686165: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 0.0개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 11428510: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 42개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 10617503: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 0.0개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 11375265: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 0.0개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 11473575: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 228개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 11606703: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 444개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 11076272: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 0.0개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 11569843: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 0.0개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 11477684: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 0.0개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 2224827: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 930개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 22개
# 필터링 후 데이터: 20개
# 제거된 데이터: 2개
#
# 제거된 기술적 알람 종류별 개수:
#   - ECG  Leads Off: 1개
#   - Resp  Leads Off: 1개
#   - NBP Interrupted: 1개
# 10965696: 20 rows saved
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 114개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 1개
# 필터링 후 데이터: 1개
# 제거된 데이터: 0개
# 10052298: 1 rows saved
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 0.0개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 4084435: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 145개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 1개
# 필터링 후 데이터: 0개
# 제거된 데이터: 1개
#
# 제거된 기술적 알람 종류별 개수:
#   - Alarms Paused: 1개
# 10994388: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 79개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 11개
# 필터링 후 데이터: 9개
# 제거된 데이터: 2개
#
# 제거된 기술적 알람 종류별 개수:
#   - PPV bad ABP Signal: 1개
#   - SpO2  Low Perf: 1개
# 11664098: 9 rows saved
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 0.0개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 11451108: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 0.0개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 2470637: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 1510개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 11580145: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 321개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 10631926: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 56개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 4개
# 필터링 후 데이터: 0개
# 제거된 데이터: 4개
#
# 제거된 기술적 알람 종류별 개수:
#   - ABP No Transducer: 2개
#   - PPV bad ABP Signal: 2개
#   - PPV  Chk Sources: 1개
# 11260662: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 290개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 5개
# 필터링 후 데이터: 5개
# 제거된 데이터: 0개
# 10810106: 5 rows saved
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 4904개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 15개
# 필터링 후 데이터: 9개
# 제거된 데이터: 6개
#
# 제거된 기술적 알람 종류별 개수:
#   - PPV bad ABP Signal: 3개
#   - ABP No Pulse: 3개
#   - Alarms Paused: 1개
# 9540350: 9 rows saved
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 0.0개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 1852164: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 0.0개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 11416329: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 0.0개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 11475729: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 0.0개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 854807: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 0.0개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 6538013: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 0.0개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 2679585: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 0.0개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 4737827: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 86개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 9870116: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 9개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 11604780: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 368개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 10599220: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 348개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 11580218: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 0.0개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 1674060: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 287개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 11664210: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 0.0개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 11383636: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 0.0개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 11375446: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 0.0개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 8864602: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 0.0개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 3679078: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 0.0개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 11391846: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 2224개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 296개
# 필터링 후 데이터: 157개
# 제거된 데이터: 139개
#
# 제거된 기술적 알람 종류별 개수:
#   - PPV bad ABP Signal: 80개
#   - ABP No Pulse: 48개
#   - Alarms Paused: 23개
#   - ABP Noisy Signal: 14개
#   - ABP Artifact: 7개
#   - ECG  Leads Off: 4개
#   - Resp  Leads Off: 4개
#   - SpO2  Low Perf: 1개
#   - SpO2  No Sensor: 1개
#   - ABP  Change Scale: 1개
#   - Tskin NoTransducer: 1개
#   - SpO2  NoisySignal: 1개
# 10996586: 157 rows saved
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 1887개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 13개
# 필터링 후 데이터: 7개
# 제거된 데이터: 6개
#
# 제거된 기술적 알람 종류별 개수:
#   - Resp  Leads Off: 3개
#   - Tskin NoTransducer: 1개
#   - Alarms Paused: 1개
#   - ECG  Leads Off: 1개
#   - ABP  Change Scale: 1개
# 11311978: 7 rows saved
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 1018개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 11602794: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 0.0개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 11410288: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 0.0개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 9689976: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 0.0개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 11434877: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 0.0개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 11404160: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 0.0개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 9522056: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 170개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 11621258: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 0.0개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 11424663: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 382개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 11318175: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 923개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 5개
# 필터링 후 데이터: 5개
# 제거된 데이터: 0개
# 9907117: 5 rows saved
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 0.0개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 2212788: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 0.0개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 1989562: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 66개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 10542010: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 113개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 13개
# 필터링 후 데이터: 8개
# 제거된 데이터: 5개
#
# 제거된 기술적 알람 종류별 개수:
#   - PPV bad ABP Signal: 3개
#   - ABP No Pulse: 2개
#   - ECG  Leads Off: 1개
#   - Resp  Leads Off: 1개
# 11666364: 8 rows saved
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 345개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 9개
# 필터링 후 데이터: 7개
# 제거된 데이터: 2개
#
# 제거된 기술적 알람 종류별 개수:
#   - Alarms Paused: 1개
#   - SpO2  Low Perf: 1개
# 11588546: 7 rows saved
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 0.0개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 3879878: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 0.0개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 453576: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 628개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 39개
# 필터링 후 데이터: 22개
# 제거된 데이터: 17개
#
# 제거된 기술적 알람 종류별 개수:
#   - SpO2  Low Perf: 7개
#   - Alarms Paused: 6개
#   - Tskin NoTransducer: 2개
#   - PPV bad ABP Signal: 1개
#   - CVP Artifact: 1개
# 11203534: 22 rows saved
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 546개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 11619279: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 0.0개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 2212828: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 0.0개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 4504548: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 75개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 22개
# 필터링 후 데이터: 13개
# 제거된 데이터: 9개
#
# 제거된 기술적 알람 종류별 개수:
#   - PPV bad ABP Signal: 3개
#   - ABP No Transducer: 2개
#   - SpO2  No Sensor: 2개
#   - ABP Artifact: 2개
#   - No Data Monitor: 1개
#   - Tskin NoTransducer: 1개
#   - Resp  Leads Off: 1개
# 10216420: 13 rows saved
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 0.0개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 2882535: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 170개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 21개
# 필터링 후 데이터: 9개
# 제거된 데이터: 12개
#
# 제거된 기술적 알람 종류별 개수:
#   - PPV bad ABP Signal: 6개
#   - Alarms Paused: 4개
#   - ABP  Change Scale: 3개
#   - ABP No Pulse: 3개
#   - Resp  Leads Off: 1개
#   - ECG  Leads Off: 1개
#   - SpO2  No Sensor: 1개
# 9667564: 9 rows saved
# 11527166: Error - invalid load key, '\x00'.
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 0.0개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 3822594: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 286개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 10695690: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 0.0개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 11387921: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 0.0개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 11467795: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 128개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 25개
# 필터링 후 데이터: 7개
# 제거된 데이터: 18개
#
# 제거된 기술적 알람 종류별 개수:
#   - PPV bad ABP Signal: 13개
#   - Alarms Paused: 7개
#   - ABP Artifact: 7개
#   - ABP No Pulse: 2개
# 11568148: 7 rows saved
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 0.0개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 11473948: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 123개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 11664413: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 9630개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 196개
# 필터링 후 데이터: 79개
# 제거된 데이터: 117개
#
# 제거된 기술적 알람 종류별 개수:
#   - ABP  Change Scale: 50개
#   - PPV bad ABP Signal: 39개
#   - ABP No Pulse: 22개
#   - Alarms Paused: 12개
#   - Tskin NoTransducer: 7개
#   - ABP Noisy Signal: 5개
#   - ABP Artifact: 2개
#   - ECG  Leads Off: 1개
#   - LL Lead Off: 1개
#   - Resp  Leads Off: 1개
#   - NBP  Equip Malf: 1개
# 11176999: 79 rows saved
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 11327개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 215개
# 필터링 후 데이터: 113개
# 제거된 데이터: 102개
#
# 제거된 기술적 알람 종류별 개수:
#   - SpO2  Low Perf: 46개
#   - Alarms Paused: 24개
#   - PPV bad ABP Signal: 12개
#   - ABP No Pulse: 8개
#   - ABP Noisy Signal: 8개
#   - ABP Artifact: 6개
#   - ECG  Leads Off: 3개
#   - Resp  Leads Off: 3개
#   - SpO2 Interference: 3개
#   - SpO2  No Sensor: 2개
#   - SpO2  NoisySignal: 1개
#   - NBP Interrupted: 1개
#   - Tskin NoTransducer: 1개
#   - SpO2  Sensor Off: 1개
# 11590699: 113 rows saved
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 0.0개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 11545645: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 0.0개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 4738097: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 0.0개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 9862193: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 0.0개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 11473971: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 152개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 11021364: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 5672개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 1285개
# 필터링 후 데이터: 1010개
# 제거된 데이터: 275개
#
# 제거된 기술적 알람 종류별 개수:
#   - SpO2  Low Perf: 116개
#   - Alarms Paused: 74개
#   - ABP Artifact: 15개
#   - SpO2 Interference: 15개
#   - SpO2  Sensor Off: 11개
#   - SpO2  NoisySignal: 10개
#   - ART No Pulse: 9개
#   - ECG  Leads Off: 7개
#   - Resp  Leads Off: 7개
#   - CVP Artifact: 7개
#   - ABP No Pulse: 6개
#   - Tskin NoTransducer: 5개
#   - ABP  Change Scale: 3개
#   - ART Noisy Signal: 3개
#   - SpO2  No Sensor: 2개
#   - ABP Noisy Signal: 1개
#   - ABP Overrange: 1개
# 10445879: 1010 rows saved
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 883개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 151개
# 필터링 후 데이터: 83개
# 제거된 데이터: 68개
#
# 제거된 기술적 알람 종류별 개수:
#   - Alarms Paused: 24개
#   - PPV bad ABP Signal: 22개
#   - ABP Artifact: 19개
#   - SpO2  Low Perf: 7개
#   - SpO2 Interference: 6개
#   - ABP No Pulse: 4개
#   - SpO2  NoisySignal: 1개
#   - ABP  Change Scale: 1개
# 11351100: 83 rows saved
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 1013개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 3개
# 필터링 후 데이터: 0개
# 제거된 데이터: 3개
#
# 제거된 기술적 알람 종류별 개수:
#   - PPV bad ABP Signal: 2개
#   - ABP  Change Scale: 2개
#   - ABP No Pulse: 1개
# 9845823: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 565개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 3개
# 필터링 후 데이터: 2개
# 제거된 데이터: 1개
#
# 제거된 기술적 알람 종류별 개수:
#   - ABP No Pulse: 1개
#   - ABP Artifact: 1개
#   - PPV bad ABP Signal: 1개
# 10200134: 2 rows saved
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 10194개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 10820683: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 0.0개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 11506768: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 0.0개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 11469906: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 262개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 11560026: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 89개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 7개
# 필터링 후 데이터: 2개
# 제거된 데이터: 5개
#
# 제거된 기술적 알람 종류별 개수:
#   - PPV bad ABP Signal: 3개
#   - ABP No Pulse: 2개
#   - SpO2  Low Perf: 1개
#   - ABP Artifact: 1개
# 11316318: 2 rows saved
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 16개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 11594847: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 564개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 11027557: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 82개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 11539565: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 0.0개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 1651826: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 0.0개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 9524347: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 0.0개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 11519112: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 0.0개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 4218004: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 4733개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 106개
# 필터링 후 데이터: 41개
# 제거된 데이터: 65개
#
# 제거된 기술적 알람 종류별 개수:
#   - Tskin NoTransducer: 38개
#   - PPV bad ABP Signal: 20개
#   - Alarms Paused: 8개
#   - ABP Noisy Signal: 1개
#   - ABP No Pulse: 1개
#   - SpO2  No Sensor: 1개
# 10138773: 41 rows saved
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 0.0개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 9489560: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 10285개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 71개
# 필터링 후 데이터: 47개
# 제거된 데이터: 24개
#
# 제거된 기술적 알람 종류별 개수:
#   - SpO2  NoisySignal: 7개
#   - SpO2  Low Perf: 5개
#   - PPV bad ABP Signal: 4개
#   - Alarms Paused: 4개
#   - ABP No Pulse: 2개
#   - SpO2 Interference: 2개
#   - ABP Noisy Signal: 1개
#   - ECG  Leads Off: 1개
#   - Resp  Leads Off: 1개
#   - SpO2  No Sensor: 1개
# 9546914: 47 rows saved
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 146개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 20개
# 필터링 후 데이터: 12개
# 제거된 데이터: 8개
#
# 제거된 기술적 알람 종류별 개수:
#   - PPV bad ABP Signal: 4개
#   - ABP Artifact: 2개
#   - Alarms Paused: 2개
#   - ABP No Pulse: 1개
# 11515043: 12 rows saved
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 20개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 11654315: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 81개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 11506865: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 4601개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 10022073: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 0.0개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 11572411: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 0.0개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 9489596: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 1085개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 11224253: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 4533개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 81개
# 필터링 후 데이터: 40개
# 제거된 데이터: 41개
#
# 제거된 기술적 알람 종류별 개수:
#   - Alarms Paused: 18개
#   - Tskin NoTransducer: 11개
#   - SpO2  NoisySignal: 5개
#   - ABP Artifact: 4개
#   - PPV bad ABP Signal: 4개
#   - SpO2 Interference: 3개
#   - SpO2  No Sensor: 1개
#   - ABP No Pulse: 1개
#   - SpO2  Sensor Off: 1개
# 11646163: 40 rows saved
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 0.0개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 2763991: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 47개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 9936087: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 77개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 7개
# 필터링 후 데이터: 3개
# 제거된 데이터: 4개
#
# 제거된 기술적 알람 종류별 개수:
#   - PPV bad ABP Signal: 1개
#   - SpO2  No Sensor: 1개
#   - Resp  Leads Off: 1개
#   - ECG  Leads Off: 1개
# 11562210: 3 rows saved
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 59개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 10052837: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 0.0개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 11451621: No rows, skipped
# 10435818: Error - Ran out of input
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 0.0개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 11422959: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 0.0개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 4142325: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 0.0개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 11508985: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 0.0개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 1957122: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 0.0개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 2692354: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 1137개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 52개
# 필터링 후 데이터: 19개
# 제거된 데이터: 33개
#
# 제거된 기술적 알람 종류별 개수:
#   - PPV bad ABP Signal: 17개
#   - ABP No Pulse: 14개
#   - SpO2  Low Perf: 5개
#   - ABP Artifact: 2개
#   - Alarms Paused: 1개
#   - ABP Noisy Signal: 1개
# 11578649: 19 rows saved
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 0.0개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 11433242: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 4526개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 144개
# 필터링 후 데이터: 88개
# 제거된 데이터: 56개
#
# 제거된 기술적 알람 종류별 개수:
#   - PPV bad ABP Signal: 20개
#   - SpO2  Low Perf: 19개
#   - ABP No Pulse: 12개
#   - ABP Artifact: 7개
#   - Alarms Paused: 3개
#   - ABP Noisy Signal: 2개
#   - ABP No Transducer: 1개
#   - Tskin NoTransducer: 1개
# 10663199: 88 rows saved
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 0.0개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 4289824: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 0.0개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 3114273: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 256개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 11304227: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 1개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 11425059: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 0.0개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 11470115: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 0.0개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 4803891: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 0.0개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 11476281: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 0.0개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 2350394: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 0.0개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 4146492: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 407개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 12개
# 필터링 후 데이터: 5개
# 제거된 데이터: 7개
#
# 제거된 기술적 알람 종류별 개수:
#   - Alarms Paused: 5개
#   - ABP No Pulse: 2개
#   - Tskin NoTransducer: 1개
#   - PPV bad ABP Signal: 1개
#   - ABP Artifact: 1개
# 11572545: 5 rows saved
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 0.0개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# ...
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 857개
# 필터링 후 데이터: 406개
# 제거된 데이터: 451개
#
# 제거된 기술적 알람 종류별 개수:
#   - PPV bad ABP Signal: 237개
#   - ABP No Pulse: 201개
#   - ABP Noisy Signal: 58개
#   - SpO2  Low Perf: 29개
#   - ABP Artifact: 14개
#   - Tskin NoTransducer: 7개
#   - SpO2  NoisySignal: 5개
#   - Alarms Paused: 5개
#   - SpO2  Sensor Off: 2개
#   - ABP Overrange: 1개
#   - Resp  Leads Off: 1개
#   - ECG  Leads Off: 1개
# 11658802: 406 rows saved
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 1549개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 39개
# 필터링 후 데이터: 21개
# 제거된 데이터: 18개
#
# 제거된 기술적 알람 종류별 개수:
#   - Alarms Paused: 8개
#   - SpO2  Low Perf: 7개
#   - ABP No Pulse: 3개
#   - ABP Artifact: 1개
# 11130422: 21 rows saved
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 0.0개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 5011003: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 229개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 3개
# 필터링 후 데이터: 3개
# 제거된 데이터: 0개
# 11515454: 3 rows saved
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 0.0개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 9287240: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 2653개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 86개
# 필터링 후 데이터: 34개
# 제거된 데이터: 52개
#
# 제거된 기술적 알람 종류별 개수:
#   - Alarms Paused: 21개
#   - ABP  Change Scale: 18개
#   - PPV bad ABP Signal: 16개
#   - ABP No Pulse: 9개
#   - SpO2  Low Perf: 4개
#   - ABP Overrange: 3개
#   - ABP Artifact: 2개
#   - ECG  Leads Off: 1개
#   - Resp  Leads Off: 1개
#   - SpO2  No Sensor: 1개
#   - ABP No Transducer: 1개
#   - ABP Disconnect: 1개
# 11669071: 34 rows saved
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 47개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 11376210: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 914개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 18개
# 필터링 후 데이터: 5개
# 제거된 데이터: 13개
#
# 제거된 기술적 알람 종류별 개수:
#   - Alarms Paused: 6개
#   - PPV bad ABP Signal: 3개
#   - PPV  Chk Sources: 2개
#   - ABP No Pulse: 2개
#   - ECG  Leads Off: 1개
#   - Resp  Leads Off: 1개
#   - SpO2  No Sensor: 1개
#   - Tskin NoTransducer: 1개
#   - ABP No Transducer: 1개
# 11568743: 5 rows saved
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 0.0개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 2616936: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 0.0개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 4134505: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 147개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 3개
# 필터링 후 데이터: 0개
# 제거된 데이터: 3개
#
# 제거된 기술적 알람 종류별 개수:
#   - ABP  Change Scale: 3개
#   - SpO2  Low Perf: 1개
# 9866864: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 0.0개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 1824370: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 262개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 11581045: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 0.0개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 11449976: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 3932개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 2개
# 필터링 후 데이터: 0개
# 제거된 데이터: 2개
#
# 제거된 기술적 알람 종류별 개수:
#   - ABP Noisy Signal: 1개
#   - ABP No Pulse: 1개
# 11439744: No rows, skipped
# Warning: Missing column: ST_numeric_time_diff_sec
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 74개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 10020486: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 0.0개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 1990288: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 0.0개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 2592401: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 0.0개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 1773202: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 0.0개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 2666140: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 0.0개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 3354269: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 18개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 12개
# 필터링 후 데이터: 3개
# 제거된 데이터: 9개
#
# 제거된 기술적 알람 종류별 개수:
#   - Alarms Paused: 5개
#   - ABP No Pulse: 4개
#   - PPV bad ABP Signal: 4개
#   - SpO2  NoisySignal: 1개
# 11558561: 3 rows saved
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 170개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 11558563: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 0.0개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 11390631: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 0.0개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 3180203: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 0.0개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 3884719: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 0.0개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 2799280: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 13105개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 308개
# 필터링 후 데이터: 122개
# 제거된 데이터: 186개
#
# 제거된 기술적 알람 종류별 개수:
#   - PPV bad ABP Signal: 82개
#   - Alarms Paused: 72개
#   - ABP No Pulse: 68개
#   - ABP Noisy Signal: 14개
#   - ABP Artifact: 14개
#   - Tskin NoTransducer: 11개
#   - ABP Disconnect: 1개
# 9963183: 122 rows saved
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 162개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 11658927: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 97개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 11개
# 필터링 후 데이터: 7개
# 제거된 데이터: 4개
#
# 제거된 기술적 알람 종류별 개수:
#   - PPV bad ABP Signal: 2개
#   - Resp  Leads Off: 1개
#   - ECG  Leads Off: 1개
#   - SpO2  No Sensor: 1개
# 11447988: 7 rows saved
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 0.0개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 4910784: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 0.0개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 3301057: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 0.0개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 4538058: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 2077개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 101개
# 필터링 후 데이터: 72개
# 제거된 데이터: 29개
#
# 제거된 기술적 알람 종류별 개수:
#   - PPV bad ABP Signal: 14개
#   - Alarms Paused: 6개
#   - ABP No Pulse: 5개
#   - ABP Artifact: 5개
#   - SpO2  NoisySignal: 3개
#   - SpO2 Interference: 3개
#   - ART No Pulse: 3개
#   - SpO2  Low Perf: 3개
#   - ECG  Leads Off: 1개
#   - ABP  Change Scale: 1개
#   - ABP Noisy Signal: 1개
# 11693779: 72 rows saved
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 113개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 11656921: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 57개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 11663074: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 108개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 10개
# 필터링 후 데이터: 5개
# 제거된 데이터: 5개
#
# 제거된 기술적 알람 종류별 개수:
#   - ABP  Change Scale: 2개
#   - PPV bad ABP Signal: 2개
#   - Tskin NoTransducer: 1개
#   - ABP No Pulse: 1개
# 10919654: 5 rows saved
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 0.0개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 2834151: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 334개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 13개
# 필터링 후 데이터: 10개
# 제거된 데이터: 3개
#
# 제거된 기술적 알람 종류별 개수:
#   - Alarms Paused: 2개
#   - SpO2  Low Perf: 1개
# 11355880: 10 rows saved
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 0.0개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 4581103: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 2571개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 28개
# 필터링 후 데이터: 8개
# 제거된 데이터: 20개
#
# 제거된 기술적 알람 종류별 개수:
#   - PPV bad ABP Signal: 12개
#   - ABP No Pulse: 9개
#   - ABP Noisy Signal: 3개
#   - SpO2  NoisySignal: 1개
#   - ABP Artifact: 1개
# 11163376: 8 rows saved
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 0.0개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 1908489: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 52개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 11개
# 필터링 후 데이터: 8개
# 제거된 데이터: 3개
#
# 제거된 기술적 알람 종류별 개수:
#   - Alarms Paused: 1개
#   - PPV bad ABP Signal: 1개
#   - ABP No Pulse: 1개
# 11321102: 8 rows saved
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 315개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 11376409: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 0.0개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 2164510: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 0.0개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 11382570: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 0.0개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 1818411: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 582개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 11056941: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 0.0개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 11431732: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 187개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 11030329: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 150개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 11개
# 필터링 후 데이터: 5개
# 제거된 데이터: 6개
#
# 제거된 기술적 알람 종류별 개수:
#   - Alarms Paused: 4개
#   - ECG  Leads Off: 2개
#   - Resp  Leads Off: 1개
#   - Tskin NoTransducer: 1개
# 11591481: 5 rows saved
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 513개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 11640636: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 0.0개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 11519814: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 5244개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 475개
# 필터링 후 데이터: 240개
# 제거된 데이터: 235개
#
# 제거된 기술적 알람 종류별 개수:
#   - ABP No Pulse: 130개
#   - Alarms Paused: 60개
#   - ABP  Change Scale: 51개
#   - ABP Noisy Signal: 4개
#   - SpO2  Low Perf: 4개
#   - NBP Check Cuff: 4개
#   - ECG Check Cable: 3개
#   - Tskin NoTransducer: 2개
#   - SpO2  No Sensor: 1개
#   - Resp  Leads Off: 1개
#   - ECG  Leads Off: 1개
#   - ABP Artifact: 1개
# 9961302: 240 rows saved
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 0.0개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 10987352: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 0.0개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 2395999: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 0.0개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 6141813: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 0.0개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 1990520: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 0.0개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 3397498: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 0.0개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 11448194: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 0.0개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 2742150: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 0.0개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 11448199: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 0.0개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 4175755: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 0.0개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 10919821: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 441개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 11550607: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 6109개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 10805145: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 1028개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 9543580: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 0.0개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 3944358: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 0.0개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 11444136: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 2390개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 11333549: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 0.0개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 11401134: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 0.0개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 3925935: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 0.0개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 11552695: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 0.0개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 2385848: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 9029개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 11286456: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 0.0개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 11505593: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 317개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 11687877: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 0.0개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 11384774: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 112개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 3개
# 필터링 후 데이터: 3개
# 제거된 데이터: 0개
# 11470790: 3 rows saved
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 0.0개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 11485130: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 0.0개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 4849615: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 424개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 11개
# 필터링 후 데이터: 6개
# 제거된 데이터: 5개
#
# 제거된 기술적 알람 종류별 개수:
#   - ABP No Pulse: 5개
#   - Alarms Paused: 2개
# 11452367: 6 rows saved
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 2343개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 8개
# 필터링 후 데이터: 3개
# 제거된 데이터: 5개
#
# 제거된 기술적 알람 종류별 개수:
#   - SpO2  Low Perf: 4개
#   - SpO2  NoisySignal: 1개
# 11618255: 3 rows saved
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 0.0개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 3184594: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 149개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 18개
# 필터링 후 데이터: 12개
# 제거된 데이터: 6개
#
# 제거된 기술적 알람 종류별 개수:
#   - ABP No Pulse: 3개
#   - PPV bad ABP Signal: 2개
#   - ABP Artifact: 1개
# 9945045: 12 rows saved
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 2001개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 7개
# 필터링 후 데이터: 4개
# 제거된 데이터: 3개
#
# 제거된 기술적 알람 종류별 개수:
#   - Alarms Paused: 1개
#   - ART No Pulse: 1개
#   - ART Artifact: 1개
#   - PAP No Transducer: 1개
# 11581406: 4 rows saved
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 0.0개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 11431914: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 156개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 11485166: No rows, skipped
#
# === In/Out 시간 일관성 체크 ===
# In/Out 시간이 일관되지 않은 알람 개수: 82개
#
# === 기술적 알람 필터링 결과 ===
# 필터링 전 데이터: 0개
# 필터링 후 데이터: 0개
# 제거된 데이터: 0개
# 11452414: No rows, skipped

# %%
import os
import pickle as pkl
import pandas as pd
from IPython.display import display

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

def load_processed_data(patient_id, data_dir='/Volumes/Seagate/pre_processed1/'):
    file_path = os.path.join(data_dir, f'{patient_id}.pkl')
    with open(file_path, 'rb') as f:
        data = pkl.load(f)
    return data

a = load_processed_data(10138773, data_dir='DATA/')
display(a)
# Out:
#        AlsUnitNo               TimeStamp  \
# 42    10138773   2024-06-19 19:37:00.757
# 43    10138773   2024-06-19 19:37:05.877
# 44    10138773   2024-06-19 19:37:10.997
# 45    10138773   2024-06-19 19:37:16.117
# 46    10138773   2024-06-19 19:37:21.237
# 47    10138773   2024-06-19 19:37:26.357
# 48    10138773   2024-06-19 19:37:31.477
# 53    10138773   2024-06-19 19:38:07.317
# 59    10138773   2024-06-19 19:38:48.277
# 61    10138773   2024-06-19 19:38:58.517
# 68    10138773   2024-06-19 19:39:49.717
# 69    10138773   2024-06-19 19:39:54.837
# 72    10138773   2024-06-19 19:40:15.317
# 73    10138773   2024-06-19 19:40:20.437
# 99    10138773   2024-06-19 19:44:56.917
# 100   10138773   2024-06-19 19:45:02.037
# 101   10138773   2024-06-19 19:45:32.757
# 102   10138773   2024-06-19 19:45:37.877
# 103   10138773   2024-06-19 19:45:42.997
# 104   10138773   2024-06-19 19:45:53.237
# 115   10138773   2024-06-19 19:50:04.117
# 117   10138773   2024-06-19 19:50:50.197
# 118   10138773   2024-06-19 19:50:55.317
# 132   10138773   2024-06-19 19:54:40.597
# 134   10138773   2024-06-19 19:55:21.557
# 135   10138773   2024-06-19 19:55:31.797
# 136   10138773   2024-06-19 19:55:36.917
# 137   10138773   2024-06-19 19:55:42.037
# 155   10138773   2024-06-19 20:00:03.157
# 158   10138773   2024-06-19 20:00:23.637
# 187   10138773   2024-06-19 20:04:14.037
# 191   10138773   2024-06-19 20:04:44.757
# 193   10138773   2024-06-19 20:04:54.997
# 229   10138773   2024-06-19 20:10:43.157
# 230   10138773   2024-06-19 20:10:48.277
# 251   10138773   2024-06-19 20:14:28.437
# 252   10138773   2024-06-19 20:14:48.917
# 253   10138773   2024-06-19 20:14:59.157
# 258   10138773   2024-06-19 20:15:40.117
# 259   10138773   2024-06-19 20:15:45.237
# 3894  10138773   2024-07-04 23:00:00.923
#
#                                                   Label  Severity  \
# 42                        [HR   111 >100, NBPs  71 <90]         2
# 43                    [NBPs  71 <90, Cannot Analyze QT]         1
# 44    [HR   111 >100, Tskin NoTransducer, Temp NoTra...         2
# 45                                       [NBPs  68 <90]         1
# 46                                  [Temp  Deactivated]         4
# 47                                  [Cannot Analyze QT]         5
# 48                                 [ABP Zero+Check Cal]         5
# 53                                      [HR   111 >100]         2
# 59                                  [Cannot Analyze QT]         5
# 61                                  [Cannot Analyze QT]         5
# 68                                  [Cannot Analyze QT]         5
# 69              [Tskin NoTransducer, Cannot Analyze QT]         4
# 72                                       [NBPs  69 <90]         1
# 73                                       [NBPs  69 <90]         1
# 99                         [NBPs  66 <90, ABPs  66 <90]         1
# 100                   [ABPs  65 <90, Cannot Analyze QT]         1
# 101   [NBPs  66 <90, ABPs  65 <90, Tskin NoTransduce...         1
# 102                  [NBPs  66 <90, Tskin NoTransducer]         1
# 103                                      [ABPs  64 <90]         1
# 104                        [NBPs  61 <90, ABPs  62 <90]         1
# 115                                      [ABPs  -1 <90]         1
# 117                  [NBPs  65 <90, PPV bad ABP Signal]         1
# 118                                      [ABPs  45 <90]         1
# 132                                 [Cannot Analyze QT]         5
# 134                        [NBPs  65 <90, ABPs  62 <90]         1
# 135                                      [SpO2  93 <95]         1
# 136                        [ABPs  83 <90, NBPs  65 <90]         1
# 137    [NBPs  85 <90, ABPs  83 <90, Tskin NoTransducer]         1
# 155                                      [SpO2  93 <95]         1
# 158                                      [SpO2  92 <95]         1
# 187                 [HR   101 >100, Tskin NoTransducer]         2
# 191                 [HR   104 >100, Tskin NoTransducer]         2
# 193                                     [HR   111 >100]         2
# 229             [Tskin NoTransducer, SpO2  Poor Signal]         4
# 230                 [SpO2  Poor Signal, SpO2  Low Perf]         5
# 251                                     [HR   101 >100]         2
# 252                                 [Cannot Analyze QT]         5
# 253             [PPV bad ABP Signal, Cannot Analyze QT]         5
# 258                                      [ABPs  85 <90]         1
# 259                       [HR   101 >100, ABPs  85 <90]         2
# 3894                                     [SpO2  88 <93]         1
#
#      SeverityColor                                       ABP_WAVEFORM  \
# 42     ShortYellow  [-50.0, -50.0, -50.0, -50.0, -50.0, -50.0, -50...
# 43          Yellow  [-50.0, -50.0, -50.0, -50.0, -50.0, -50.0, -50...
# 44     ShortYellow  [-50.0, -50.0, -50.0, -50.0, -50.0, -50.0, -50...
# 45          Yellow  [-50.0, -50.0, -50.0, -50.0, -50.0, -50.0, -50...
# 46            Cyan  [-50.0, -50.0, -50.0, -50.0, -50.0, -50.0, -50...
# 47      SilentCyan  [-50.0, -50.0, -50.0, -50.0, -50.0, -50.0, -50...
# 48      SilentCyan  [-50.0, -50.0, -50.0, -50.0, -50.0, -50.0, -50...
# 53     ShortYellow  [16.4375, 16.25, 16.0625, 15.875, 15.8125, 15....
# 59      SilentCyan  [24.3125, 24.1875, 24.0625, 24.0, 23.9375, 23....
# 61      SilentCyan  [22.4375, 22.625, 22.75, 22.875, 23.0, 23.0, 2...
# 68      SilentCyan  [9.0625, 7.4375, 6.0625, 5.1875, 4.75, 4.8125,...
# 69            Cyan  [9.3125, 9.125, 8.8125, 8.625, 8.625, 8.9375, ...
# 72          Yellow  [9.9375, 9.8125, 9.75, 9.75, 9.875, 10.0625, 1...
# 73          Yellow  [10.75, 10.8125, 10.6875, 10.375, 10.0625, 9.8...
# 99          Yellow  [56.5625, 54.6875, 52.75, 50.8125, 49.0, 47.25...
# 100         Yellow  [50.6875, 49.1875, 47.6875, 46.125, 44.5625, 4...
# 101         Yellow  [40.5625, 38.25, 36.1875, 34.5625, 33.5, 32.87...
# 102         Yellow  [27.875, 27.8125, 27.8125, 27.875, 28.1875, 28...
# 103         Yellow  [36.0625, 30.625, 26.0625, 24.25, 25.375, 27.9...
# 104         Yellow  [59.1875, 57.875, 56.75, 55.75, 54.6875, 53.62...
# 115         Yellow  [26.9375, 26.875, 26.75, 26.625, 26.5, 26.4375...
# 117         Yellow  [44.9375, 44.9375, 44.875, 44.875, 44.9375, 45...
# 118         Yellow  [58.4375, 57.5625, 56.5, 55.4375, 54.4375, 53....
# 132     SilentCyan  [48.5, 48.5, 48.5625, 48.6875, 49.0, 49.6875, ...
# 134         Yellow  [59.3125, 58.9375, 58.375, 57.625, 56.875, 56....
# 135         Yellow  [56.4375, 56.25, 56.125, 56.125, 56.125, 56.12...
# 136         Yellow  [53.1875, 54.375, 56.75, 60.6875, 66.25, 72.75...
# 137         Yellow  [81.1875, 81.125, 80.75, 80.3125, 79.9375, 79....
# 155         Yellow  [80.6875, 80.75, 80.375, 79.6875, 78.625, 77.3...
# 158         Yellow  [81.4375, 81.3125, 80.625, 79.5625, 78.25, 76....
# 187    ShortYellow  [102.0, 103.75, 105.5625, 107.1875, 108.5, 109...
# 191    ShortYellow  [109.5, 107.0625, 103.4375, 99.75, 96.6875, 94...
# 193    ShortYellow  [103.25, 104.3125, 104.1875, 102.25, 98.625, 9...
# 229           Cyan  [78.625, 77.9375, 74.875, 70.875, 67.1875, 64....
# 230     SilentCyan  [60.0, 59.25, 59.0, 59.3125, 60.0, 61.0, 62.31...
# 251    ShortYellow  [74.0625, 71.6875, 70.5, 70.3125, 70.9375, 71....
# 252     SilentCyan  [99.5, 101.9375, 101.6875, 99.4375, 95.9375, 9...
# 253     SilentCyan  [64.75, 64.6875, 64.6875, 64.6875, 64.5, 64.12...
# 258         Yellow  [60.375, 60.0625, 59.75, 59.5, 59.25, 59.0, 58...
# 259    ShortYellow  [87.5, 86.625, 85.875, 85.5, 85.5, 85.875, 86....
# 3894        Yellow  [96.875, 96.3125, 95.3125, 94.0, 92.625, 91.18...
#
#                                            ECG_WAVEFORM  \
# 42    [0.55, 0.59, 0.585, 0.525, 0.465, 0.505, 0.54,...
# 43    [0.43, 0.43, 0.42, 0.435, 0.455, 0.455, 0.44, ...
# 44    [0.43, 0.45, 0.435, 0.435, 0.425, 0.44, 0.435,...
# 45    [0.53, 0.5, 0.49, 0.54, 0.56, 0.52, 0.485, 0.5...
# 46    [0.66, 0.595, 0.625, 0.73, 0.665, 0.57, 0.6, 0...
# 47    [0.59, 0.56, 0.525, 0.565, 0.62, 0.6, 0.535, 0...
# 48    [0.525, 0.515, 0.45, 0.48, 0.515, 0.475, 0.41,...
# 53    [0.695, 0.705, 0.65, 0.645, 0.68, 0.68, 0.665,...
# 59    [0.45, 0.435, 0.38, 0.395, 0.41, 0.4, 0.385, 0...
# 61    [0.65, 0.65, 0.715, 0.735, 0.64, 0.625, 0.725,...
# 68    [1.34, 1.295, 1.18, 1.0, 0.825, 0.685, 0.545, ...
# 69    [0.595, 0.63, 0.62, 0.58, 0.61, 0.625, 0.595, ...
# 72    [0.46, 0.52, 0.535, 0.47, 0.45, 0.53, 0.565, 0...
# 73    [0.525, 0.535, 0.53, 0.535, 0.565, 0.57, 0.56,...
# 99    [-0.25, -0.185, -0.185, -0.26, -0.29, -0.26, -...
# 100   [0.035, 0.085, 0.115, 0.065, 0.05, 0.125, 0.16...
# 101   [1.005, 0.97, 1.055, 1.11, 1.05, 1.01, 1.025, ...
# 102   [0.44, 0.4, 0.395, 0.385, 0.33, 0.295, 0.36, 0...
# 103   [0.525, 0.57, 0.555, 0.525, 0.55, 0.595, 0.55,...
# 104   [0.07, 0.03, -0.03, 0.05, 0.14, 0.12, 0.035, 0...
# 115   [0.58, 0.605, 0.66, 0.635, 0.58, 0.575, 0.64, ...
# 117   [0.605, 0.565, 0.555, 0.6, 0.635, 0.59, 0.535,...
# 118   [0.63, 0.63, 0.56, 0.54, 0.61, 0.615, 0.57, 0....
# 132   [0.61, 0.635, 0.625, 0.58, 0.585, 0.625, 0.625...
# 134   [0.58, 0.525, 0.43, 0.385, 0.395, 0.375, 0.315...
# 135   [0.605, 0.635, 0.635, 0.6, 0.595, 0.63, 0.64, ...
# 136   [0.48, 0.485, 0.505, 0.495, 0.455, 0.46, 0.505...
# 137   [0.63, 0.64, 0.605, 0.595, 0.64, 0.68, 0.605, ...
# 155   [0.525, 0.535, 0.535, 0.475, 0.46, 0.495, 0.54...
# 158   [0.43, 0.525, 0.575, 0.515, 0.46, 0.495, 0.54,...
# 187   [0.51, 0.47, 0.52, 0.52, 0.48, 0.485, 0.535, 0...
# 191   [0.55, 0.58, 0.595, 0.6, 0.635, 0.595, 0.52, 0...
# 193   [0.535, 0.46, 0.455, 0.53, 0.575, 0.495, 0.435...
# 229   [1.41, 1.47, 1.29, 1.005, 0.825, 0.75, 0.545, ...
# 230   [0.465, 0.395, 0.44, 0.49, 0.475, 0.48, 0.575,...
# 251   [0.455, 0.48, 0.525, 0.505, 0.51, 0.55, 0.57, ...
# 252   [0.52, 0.48, 0.515, 0.525, 0.51, 0.51, 0.55, 0...
# 253   [1.3, 1.255, 1.165, 1.015, 0.855, 0.73, 0.595,...
# 258   [0.5, 0.425, 0.375, 0.4, 0.445, 0.41, 0.435, 0...
# 259   [0.465, 0.49, 0.51, 0.515, 0.525, 0.54, 0.515,...
# 3894  [0.41, 0.395, 0.425, 0.425, 0.415, 0.405, 0.43...
#
#                                            PPG_WAVEFORM  \
# 42    [0.3232421875, 0.3193359375, 0.31298828125, 0....
# 43    [0.59814453125, 0.58935546875, 0.58154296875, ...
# 44    [-0.13623046875, -0.140625, -0.1455078125, -0....
# 45    [-0.48828125, -0.494140625, -0.4970703125, -0....
# 46    [-0.0185546875, -0.03369140625, -0.04443359375...
# 47    [0.18505859375, 0.18896484375, 0.1943359375, 0...
# 48    [0.05908203125, 0.06201171875, 0.06640625, 0.0...
# 53    [0.1171875, 0.12451171875, 0.130859375, 0.1357...
# 59    [-0.0498046875, -0.05029296875, -0.04931640625...
# 61    [0.1806640625, 0.1376953125, 0.09912109375, 0....
# 68    [0.9599609375, 0.95751953125, 0.94482421875, 0...
# 69    [0.083984375, 0.0830078125, 0.08154296875, 0.0...
# 72    [0.33203125, 0.28955078125, 0.2509765625, 0.21...
# 73    [0.1611328125, 0.171875, 0.193359375, 0.227539...
# 99    [0.13427734375, 0.12744140625, 0.12060546875, ...
# 100   [0.130859375, 0.12255859375, 0.11474609375, 0....
# 101   [0.98046875, 1.01220703125, 1.04541015625, 1.0...
# 102   [0.66455078125, 0.681640625, 0.69970703125, 0....
# 103   [0.7314453125, 0.73193359375, 0.73193359375, 0...
# 104   [0.10107421875, 0.0986328125, 0.095703125, 0.0...
# 115   [0.25146484375, 0.24853515625, 0.244140625, 0....
# 117   [0.19482421875, 0.20947265625, 0.23876953125, ...
# 118   [-0.02783203125, -0.03662109375, -0.044921875,...
# 132   [0.34130859375, 0.32958984375, 0.31884765625, ...
# 134   [0.75830078125, 0.72900390625, 0.701171875, 0....
# 135   [0.91162109375, 0.9140625, 0.91455078125, 0.91...
# 136   [1.025390625, 1.00927734375, 0.994140625, 0.97...
# 137   [0.09033203125, 0.0751953125, 0.05908203125, 0...
# 155   [0.24755859375, 0.29541015625, 0.35400390625, ...
# 158   [0.41064453125, 0.4140625, 0.4169921875, 0.419...
# 187   [0.21875, 0.21240234375, 0.2080078125, 0.20361...
# 191   [0.2080078125, 0.197265625, 0.1865234375, 0.17...
# 193   [0.55517578125, 0.54931640625, 0.541015625, 0....
# 229   [1.33349609375, 1.34375, 1.3486328125, 1.34863...
# 230   [0.43994140625, 0.4267578125, 0.41650390625, 0...
# 251   [0.63330078125, 0.63232421875, 0.6318359375, 0...
# 252   [0.42822265625, 0.4189453125, 0.408203125, 0.3...
# 253   [0.796875, 0.7919921875, 0.78857421875, 0.7841...
# 258   [0.51318359375, 0.51171875, 0.51123046875, 0.5...
# 259   [0.80419921875, 0.79150390625, 0.77783203125, ...
# 3894  [0.125, 0.1201171875, 0.11572265625, 0.1113281...
#
#                                           RESP_WAVEFORM  ABP_time_diff_sec  \
# 42    [1.7501527183872938, 1.7336591325595603, 1.686...              30.72
# 43    [-0.7513744654856445, -0.7513744654856445, -0....              25.60
# 44    [0.27550397067806964, 0.2180818570555895, 0.16...              20.48
# 45    [-0.11606597434331094, -0.11973121563836286, -...              15.36
# 46    [-0.39706780696395844, -0.4129505192425168, -0...              10.24
# 47    [0.8338423946243128, 0.8356750152718387, 0.840...               5.12
# 48    [-0.31093463653023823, -0.3213194868662187, -0...               0.00
# 53    [-0.3335369578497251, -0.3323152107513745, -0....               0.00
# 59    [0.9517409896151496, 0.9804520464263897, 1.012...               0.00
# 61    [1.4599877825290164, 1.4557116676847892, 1.445...               0.00
# 68    [-0.19364691508857668, -0.18448381185094687, -...               0.00
# 69    [0.32559560171044594, 0.30482590103848506, 0.2...               0.00
# 72    [-0.13439218081857054, -0.13378130726939524, -...               0.00
# 73    [-0.22480146609651802, -0.2180818570555895, -0...               0.00
# 99    [-0.15760537568723273, -0.16188149053145998, -...               0.00
# 100   [0.17165546731826511, 0.1912034208918754, 0.21...               0.00
# 101   [-0.44593769089798413, -0.4392180818570556, -0...               0.00
# 102   [0.8106291997556506, 0.8259010384850336, 0.838...               0.00
# 103   [0.6841783750763591, 0.7153329260843005, 0.745...               0.00
# 104   [0.18204031765424558, 0.13194868662186926, 0.0...               0.00
# 115   [-0.3274282223579719, -0.321930360415394, -0.3...               0.00
# 117   [0.11667684789248625, 0.1594379963347587, 0.20...               0.00
# 118   [-0.16615760537568725, -0.17654245571166768, -...               0.00
# 132   [0.373243738546121, 0.3879047037263286, 0.3970...               0.00
# 134   [1.2974954184483811, 1.3115455100794136, 1.323...               0.00
# 135   [-0.29871716554673183, -0.28833231521075137, -...               0.00
# 136   [0.8814905314599878, 0.8326206475259621, 0.779...               0.00
# 137   [-0.2651191203420892, -0.28100183262064754, -0...               0.00
# 155   [0.24434941967012827, 0.2235797189981674, 0.20...               0.00
# 158   [0.9969456322541234, 1.034208918753818, 1.0690...               0.00
# 187   [0.15210751374465487, 0.12522907758094073, 0.0...               0.00
# 191   [0.9236408063530849, 0.874160048869884, 0.8210...               0.00
# 193   [-0.24312767257177764, -0.22907758094074526, -...               0.00
# 229   [-0.36530238240684176, -0.35858277336591327, -...               0.00
# 230   [0.5198533903481979, 0.5058032987171656, 0.489...               0.00
# 251   [0.2296884544899206, 0.21991447770311545, 0.20...               0.00
# 252   [0.8546120952962737, 0.870494807574832, 0.8857...               0.00
# 253   [-0.22663408674404398, -0.2156383628588882, -0...               0.00
# 258   [0.7782529016493586, 0.8265119120342089, 0.872...               0.00
# 259   [0.43555284056200366, 0.40623091020158825, 0.3...               0.00
# 3894  [-0.19303604153940135, -0.19609040928527796, -...               0.00
#
#       II_time_diff_sec  Pleth_time_diff_sec  Resp_time_diff_sec  SpO2_numeric  \
# 42                 0.0                  0.0                 0.0          99.9
# 43                 0.0                  0.0                 0.0          99.9
# 44                 0.0                  0.0                 0.0          99.9
# 45                 0.0                  0.0                 0.0          99.2
# 46                 0.0                  0.0                 0.0          98.1
# 47                 0.0                  0.0                 0.0          98.4
# 48                 0.0                  0.0                 0.0          99.0
# 53                 0.0                  0.0                 0.0          98.9
# 59                 0.0                  0.0                 0.0          98.6
# 61                 0.0                  0.0                 0.0          98.0
# 68                 0.0                  0.0                 0.0          98.9
# 69                 0.0                  0.0                 0.0          98.9
# 72                 0.0                  0.0                 0.0          98.7
# 73                 0.0                  0.0                 0.0          98.6
# 99                 0.0                  0.0                 0.0          99.1
# 100                0.0                  0.0                 0.0          98.8
# 101                0.0                  0.0                 0.0         100.0
# 102                0.0                  0.0                 0.0         100.0
# 103                0.0                  0.0                 0.0         100.0
# 104                0.0                  0.0                 0.0         100.0
# 115                0.0                  0.0                 0.0          97.4
# 117                0.0                  0.0                 0.0          96.7
# 118                0.0                  0.0                 0.0          96.6
# 132                0.0                  0.0                 0.0          95.9
# 134                0.0                  0.0                 0.0          95.3
# 135                0.0                  0.0                 0.0          92.7
# 136                0.0                  0.0                 0.0          92.7
# 137                0.0                  0.0                 0.0          94.7
# 155                0.0                  0.0                 0.0          94.1
# 158                0.0                  0.0                 0.0          93.4
# 187                0.0                  0.0                 0.0          93.7
# 191                0.0                  0.0                 0.0          95.6
# 193                0.0                  0.0                 0.0          95.7
# 229                0.0                  0.0                 0.0          95.9
# 230                0.0                  0.0                 0.0          95.1
# 251                0.0                  0.0                 0.0          98.4
# 252                0.0                  0.0                 0.0          96.7
# 253                0.0                  0.0                 0.0          97.5
# 258                0.0                  0.0                 0.0          99.3
# 259                0.0                  0.0                 0.0         100.0
# 3894               0.0                  0.0                 0.0          92.4
#
#       Pulse_numeric  ST_numeric  Tskin_numeric  ABP_numeric  NBP_numeric  \
# 42            106.0        -0.2            NaN          NaN         49.0
# 43            106.0        -0.2            NaN          NaN         49.0
# 44            106.0         0.0            NaN          NaN         49.0
# 45            106.0         0.0            NaN          NaN         50.0
# 46            106.0         0.0            NaN          NaN         50.0
# 47            104.0         0.0            NaN          NaN         50.0
# 48            105.0         0.0            NaN          NaN         50.0
# 53            105.0        -0.1            NaN          NaN         50.0
# 59            103.0         0.0            NaN          NaN         50.0
# 61            105.0         0.1            NaN          NaN         50.0
# 68            102.0         0.0          35.78          NaN         39.0
# 69            102.0         0.0          35.77          NaN         39.0
# 72            102.0         0.1            NaN          NaN         48.0
# 73            102.0         0.1          35.76          NaN         48.0
# 99             95.0         0.0            NaN         68.0         38.0
# 100            94.0         0.0            NaN         67.0         38.0
# 101            93.0        -0.1            NaN         66.0         38.0
# 102            93.0        -0.1            NaN         29.0         38.0
# 103            93.0        -0.1            NaN         29.0         38.0
# 104            93.0        -0.1            NaN         65.0         38.0
# 115            78.0         0.0            NaN         27.0         42.0
# 117            74.0         0.0            NaN         63.0         42.0
# 118            75.0         0.0            NaN         55.0         42.0
# 132            84.0         0.2            NaN         56.0         74.0
# 134            93.0         0.0            NaN         87.0         85.0
# 135            85.0         0.0            NaN         64.0         85.0
# 136            85.0         0.1            NaN         63.0         85.0
# 137            85.0         0.1            NaN         50.0         85.0
# 155            93.0         0.2            NaN         60.0         85.0
# 158            93.0         0.2            NaN         78.0         85.0
# 187            99.0         0.2            NaN         65.0         88.0
# 191            99.0         0.2            NaN         83.0         88.0
# 193            99.0         0.1            NaN         82.0         88.0
# 229            98.0         0.2            NaN         75.0         96.0
# 230            97.0         0.2            NaN         77.0         96.0
# 251            97.0         0.2            NaN         61.0         88.0
# 252           102.0         0.2            NaN        101.0         88.0
# 253            98.0         0.2            NaN        101.0         88.0
# 258            99.0         0.2            NaN         86.0         73.0
# 259           100.0         0.2            NaN         59.0         73.0
# 3894           71.0        -0.2          36.33         52.0         90.0
#
#       HR_numeric  RR_numeric  SpO2_numeric_time_diff_sec  \
# 42         104.0        18.0                       0.190
# 43         107.0        18.0                       0.190
# 44         106.0        16.0                       0.190
# 45         105.0        18.0                       0.190
# 46         104.0        16.0                       0.480
# 47         106.0        16.0                       0.480
# 48         106.0        16.0                       0.480
# 53         107.0        17.0                       0.320
# 59         104.0        17.0                       0.320
# 61         104.0        18.0                       0.320
# 68         104.0        15.0                       0.320
# 69         103.0        15.0                       0.320
# 72         102.0        16.0                       0.320
# 73         100.0        16.0                       0.320
# 99          94.0        21.0                       0.320
# 100         96.0        21.0                       0.320
# 101         90.0        18.0                       0.320
# 102         90.0        18.0                       0.320
# 103         90.0        18.0                       0.320
# 104         92.0        20.0                       0.320
# 115         78.0        21.0                       0.320
# 117         76.0        18.0                       0.320
# 118         78.0        19.0                       0.320
# 132         85.0        22.0                       0.320
# 134         88.0        22.0                       0.320
# 135         86.0        25.0                       0.320
# 136         87.0        25.0                       0.190
# 137         86.0        24.0                       0.320
# 155         95.0        21.0                       0.320
# 158         94.0        20.0                       0.320
# 187        100.0        20.0                       0.320
# 191         98.0        20.0                       0.320
# 193        101.0        21.0                       0.320
# 229         97.0        16.0                       0.320
# 230         97.0        17.0                       0.320
# 251         99.0        15.0                       0.320
# 252         98.0        19.0                       0.320
# 253         97.0        18.0                       0.320
# 258         98.0        18.0                       0.320
# 259         98.0        20.0                       0.320
# 3894        71.0        20.0                       0.097
#
#       Pulse_numeric_time_diff_sec  ST_numeric_time_diff_sec  \
# 42                          0.190                     0.190
# 43                          0.190                     0.190
# 44                          0.190                     0.190
# 45                          0.190                     0.190
# 46                          0.480                     0.480
# 47                          0.480                     0.480
# 48                          0.480                     0.480
# 53                          0.320                     0.320
# 59                          0.320                     0.320
# 61                          0.320                     0.320
# 68                          0.320                     0.320
# 69                          0.320                     0.320
# 72                          0.320                     0.320
# 73                          0.320                     0.320
# 99                          0.320                     0.320
# 100                         0.320                     0.320
# 101                         0.320                     0.320
# 102                         0.320                     0.320
# 103                         0.320                     0.320
# 104                         0.320                     0.320
# 115                         0.320                     0.320
# 117                         0.320                     0.320
# 118                         0.320                     0.320
# 132                         0.320                     0.320
# 134                         0.320                     0.320
# 135                         0.320                     0.320
# 136                         0.190                     0.190
# 137                         0.320                     0.320
# 155                         0.320                     0.320
# 158                         0.320                     0.320
# 187                         0.320                     0.320
# 191                         0.320                     0.320
# 193                         0.320                     0.320
# 229                         0.320                     0.320
# 230                         0.320                     0.320
# 251                         0.320                     0.320
# 252                         0.320                     0.320
# 253                         0.320                     0.320
# 258                         0.320                     0.320
# 259                         0.320                     0.320
# 3894                        0.097                     0.097
#
#       Tskin_numeric_time_diff_sec  ABP_numeric_time_diff_sec  \
# 42                          0.190                     32.480
# 43                          0.190                     27.360
# 44                          0.190                     22.240
# 45                          0.190                     17.120
# 46                          1.214                     12.000
# 47                          6.334                      6.880
# 48                         11.454                      1.760
# 53                         25.280                      0.320
# 59                          0.320                      0.320
# 61                          0.320                      0.320
# 68                          0.320                      0.320
# 69                          0.320                      0.320
# 72                          0.320                      0.320
# 73                          0.320                      0.320
# 99                          0.320                      0.320
# 100                         0.320                      0.320
# 101                         0.320                      0.320
# 102                         0.320                      0.320
# 103                         0.320                      0.320
# 104                         8.510                      0.320
# 115                         0.320                      0.320
# 117                         0.320                      0.320
# 118                         0.320                      0.317
# 132                         0.320                      0.320
# 134                         0.320                      0.320
# 135                         0.320                      0.320
# 136                         0.190                      0.190
# 137                         0.320                      0.320
# 155                         0.320                      0.320
# 158                         0.320                      0.320
# 187                         0.320                      0.320
# 191                         0.320                      0.320
# 193                         0.320                      0.320
# 229                         0.320                      0.320
# 230                         0.320                      0.320
# 251                         0.320                      0.320
# 252                         0.320                      0.320
# 253                         0.320                      0.320
# 258                         0.320                      0.320
# 259                         0.320                      0.320
# 3894                        0.097                      0.097
#
#       NBP_numeric_time_diff_sec  HR_numeric_time_diff_sec  \
# 42                       36.757                     0.190
# 43                       41.877                     0.190
# 44                       46.997                     0.190
# 45                       48.883                     0.190
# 46                       43.763                     0.480
# 47                       38.643                     0.480
# 48                       33.523                     0.480
# 53                        2.317                     0.320
# 59                       43.277                     0.320
# 61                       53.517                     0.320
# 68                       10.283                     0.320
# 69                        5.163                     0.320
# 72                       15.317                     0.320
# 73                       20.437                     0.320
# 99                        3.083                     0.320
# 100                       2.037                     0.320
# 101                      32.757                     0.320
# 102                      37.877                     0.320
# 103                      42.997                     0.320
# 104                      53.237                     0.320
# 115                       4.117                     0.320
# 117                      50.197                     0.320
# 118                      55.317                     0.320
# 132                      19.403                     0.320
# 134                      21.557                     0.320
# 135                      31.797                     0.320
# 136                      36.917                     0.190
# 137                      42.037                     0.320
# 155                       3.157                     0.320
# 158                      23.637                     0.320
# 187                      45.963                     0.320
# 191                      15.243                     0.320
# 193                       5.003                     0.320
# 229                      43.157                     0.320
# 230                      48.277                     0.320
# 251                      31.563                     0.320
# 252                      11.083                     0.320
# 253                       0.843                     0.320
# 258                      40.117                     0.320
# 259                      45.237                     0.320
# 3894                      0.923                     0.097
#
#       RR_numeric_time_diff_sec  \
# 42                       0.190
# 43                       0.190
# 44                       0.190
# 45                       0.190
# 46                       0.480
# 47                       0.480
# 48                       0.480
# 53                       0.320
# 59                       0.320
# 61                       0.320
# 68                       0.320
# 69                       0.320
# 72                       0.320
# 73                       0.320
# 99                       0.320
# 100                      0.320
# 101                      0.320
# 102                      0.320
# 103                      0.320
# 104                      0.320
# 115                      0.320
# 117                      0.320
# 118                      0.320
# 132                      0.320
# 134                      0.320
# 135                      0.320
# 136                      0.190
# 137                      0.320
# 155                      0.320
# 158                      0.320
# 187                      0.320
# 191                      0.320
# 193                      0.320
# 229                      0.320
# 230                      0.320
# 251                      0.320
# 252                      0.320
# 253                      0.320
# 258                      0.320
# 259                      0.320
# 3894                     0.097
#
#                                     NursingRecords_ba30          AdmissionIn  \
# 42    [{'시행일시': 2024-06-19 19:20:00, '간호진단프로토콜(코드명)'...  2024-06-19 19:16:08
# 43    [{'시행일시': 2024-06-19 19:20:00, '간호진단프로토콜(코드명)'...  2024-06-19 19:16:08
# 44    [{'시행일시': 2024-06-19 19:20:00, '간호진단프로토콜(코드명)'...  2024-06-19 19:16:08
# 45    [{'시행일시': 2024-06-19 19:20:00, '간호진단프로토콜(코드명)'...  2024-06-19 19:16:08
# 46    [{'시행일시': 2024-06-19 19:20:00, '간호진단프로토콜(코드명)'...  2024-06-19 19:16:08
# 47    [{'시행일시': 2024-06-19 19:20:00, '간호진단프로토콜(코드명)'...  2024-06-19 19:16:08
# 48    [{'시행일시': 2024-06-19 19:20:00, '간호진단프로토콜(코드명)'...  2024-06-19 19:16:08
# 53    [{'시행일시': 2024-06-19 19:20:00, '간호진단프로토콜(코드명)'...  2024-06-19 19:16:08
# 59    [{'시행일시': 2024-06-19 19:20:00, '간호진단프로토콜(코드명)'...  2024-06-19 19:16:08
# 61    [{'시행일시': 2024-06-19 19:20:00, '간호진단프로토콜(코드명)'...  2024-06-19 19:16:08
# 68    [{'시행일시': 2024-06-19 19:20:00, '간호진단프로토콜(코드명)'...  2024-06-19 19:16:08
# 69    [{'시행일시': 2024-06-19 19:20:00, '간호진단프로토콜(코드명)'...  2024-06-19 19:16:08
# 72    [{'시행일시': 2024-06-19 19:20:00, '간호진단프로토콜(코드명)'...  2024-06-19 19:16:08
# 73    [{'시행일시': 2024-06-19 19:20:00, '간호진단프로토콜(코드명)'...  2024-06-19 19:16:08
# 99    [{'시행일시': 2024-06-19 19:20:00, '간호진단프로토콜(코드명)'...  2024-06-19 19:16:08
# 100   [{'시행일시': 2024-06-19 19:20:00, '간호진단프로토콜(코드명)'...  2024-06-19 19:16:08
# 101   [{'시행일시': 2024-06-19 19:20:00, '간호진단프로토콜(코드명)'...  2024-06-19 19:16:08
# 102   [{'시행일시': 2024-06-19 19:20:00, '간호진단프로토콜(코드명)'...  2024-06-19 19:16:08
# 103   [{'시행일시': 2024-06-19 19:20:00, '간호진단프로토콜(코드명)'...  2024-06-19 19:16:08
# 104   [{'시행일시': 2024-06-19 19:20:00, '간호진단프로토콜(코드명)'...  2024-06-19 19:16:08
# 115   [{'시행일시': 2024-06-19 19:30:00, '간호진단프로토콜(코드명)'...  2024-06-19 19:16:08
# 117   [{'시행일시': 2024-06-19 19:30:00, '간호진단프로토콜(코드명)'...  2024-06-19 19:16:08
# 118   [{'시행일시': 2024-06-19 19:30:00, '간호진단프로토콜(코드명)'...  2024-06-19 19:16:08
# 132   [{'시행일시': 2024-06-19 19:30:00, '간호진단프로토콜(코드명)'...  2024-06-19 19:16:08
# 134   [{'시행일시': 2024-06-19 19:30:00, '간호진단프로토콜(코드명)'...  2024-06-19 19:16:08
# 135   [{'시행일시': 2024-06-19 19:30:00, '간호진단프로토콜(코드명)'...  2024-06-19 19:16:08
# 136   [{'시행일시': 2024-06-19 19:30:00, '간호진단프로토콜(코드명)'...  2024-06-19 19:16:08
# 137   [{'시행일시': 2024-06-19 19:30:00, '간호진단프로토콜(코드명)'...  2024-06-19 19:16:08
# 155   [{'시행일시': 2024-06-19 19:40:00, '간호진단프로토콜(코드명)'...  2024-06-19 19:16:08
# 158   [{'시행일시': 2024-06-19 19:40:00, '간호진단프로토콜(코드명)'...  2024-06-19 19:16:08
# 187   [{'시행일시': 2024-06-19 19:40:00, '간호진단프로토콜(코드명)'...  2024-06-19 19:16:08
# 191   [{'시행일시': 2024-06-19 19:40:00, '간호진단프로토콜(코드명)'...  2024-06-19 19:16:08
# 193   [{'시행일시': 2024-06-19 19:40:00, '간호진단프로토콜(코드명)'...  2024-06-19 19:16:08
# 229   [{'시행일시': 2024-06-19 19:43:00, '간호진단프로토콜(코드명)'...  2024-06-19 19:16:08
# 230   [{'시행일시': 2024-06-19 19:43:00, '간호진단프로토콜(코드명)'...  2024-06-19 19:16:08
# 251   [{'시행일시': 2024-06-19 19:50:00, '간호진단프로토콜(코드명)'...  2024-06-19 19:16:08
# 252   [{'시행일시': 2024-06-19 19:50:00, '간호진단프로토콜(코드명)'...  2024-06-19 19:16:08
# 253   [{'시행일시': 2024-06-19 19:50:00, '간호진단프로토콜(코드명)'...  2024-06-19 19:16:08
# 258   [{'시행일시': 2024-06-19 19:50:00, '간호진단프로토콜(코드명)'...  2024-06-19 19:16:08
# 259   [{'시행일시': 2024-06-19 19:50:00, '간호진단프로토콜(코드명)'...  2024-06-19 19:16:08
# 3894  [{'시행일시': 2024-07-04 22:40:00, '간호진단프로토콜(코드명)'...  2024-07-03 09:31:56
#
#              AdmissionOut  isView  isSelected  Classification Comment
# 42    2024-06-22 15:10:52    True       False           False
# 43    2024-06-22 15:10:52    True       False           False
# 44    2024-06-22 15:10:52    True       False           False
# 45    2024-06-22 15:10:52    True       False           False
# 46    2024-06-22 15:10:52    True       False           False
# 47    2024-06-22 15:10:52    True       False           False
# 48    2024-06-22 15:10:52    True       False           False
# 53    2024-06-22 15:10:52    True       False           False
# 59    2024-06-22 15:10:52    True       False           False
# 61    2024-06-22 15:10:52    True       False           False
# 68    2024-06-22 15:10:52    True       False           False
# 69    2024-06-22 15:10:52    True       False           False
# 72    2024-06-22 15:10:52    True       False           False
# 73    2024-06-22 15:10:52    True       False           False
# 99    2024-06-22 15:10:52    True       False           False
# 100   2024-06-22 15:10:52    True       False           False
# 101   2024-06-22 15:10:52    True       False           False
# 102   2024-06-22 15:10:52    True       False           False
# 103   2024-06-22 15:10:52    True       False           False
# 104   2024-06-22 15:10:52    True       False           False
# 115   2024-06-22 15:10:52    True       False           False
# 117   2024-06-22 15:10:52    True       False           False
# 118   2024-06-22 15:10:52    True       False           False
# 132   2024-06-22 15:10:52    True       False           False
# 134   2024-06-22 15:10:52    True       False           False
# 135   2024-06-22 15:10:52    True       False           False
# 136   2024-06-22 15:10:52    True       False           False
# 137   2024-06-22 15:10:52    True       False           False
# 155   2024-06-22 15:10:52    True       False           False
# 158   2024-06-22 15:10:52    True       False           False
# 187   2024-06-22 15:10:52    True       False           False
# 191   2024-06-22 15:10:52    True       False           False
# 193   2024-06-22 15:10:52    True       False           False
# 229   2024-06-22 15:10:52    True       False           False
# 230   2024-06-22 15:10:52    True       False           False
# 251   2024-06-22 15:10:52    True       False           False
# 252   2024-06-22 15:10:52    True       False           False
# 253   2024-06-22 15:10:52    True       False           False
# 258   2024-06-22 15:10:52    True       False           False
# 259   2024-06-22 15:10:52    True       False           False
# 3894                         True       False           False

# %%
# Out:
# 2
